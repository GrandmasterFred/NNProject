# %% [markdown]
#  # this file will try to trian the two models defined here. And determine which is the best performing one

# %%
from torch.nn import Module, Sequential, LeakyReLU, Conv2d, BatchNorm2d, AvgPool2d, MaxPool2d, AdaptiveAvgPool2d, Linear, Dropout
import torch
from torchinfo import summary

# this is adapted from https://github.com/Moeo3/GoogLeNet-Inception-V3-pytorch/blob/master/googlenet_v3.py#L58 with its size modified to suit the CIFAR10 dataset instead of the origianl ImageNet dataset.

''' comments on models
the orignal model has
3 conv_bn
1 pool
2 conv_bn
1 pool
3x inception a
1x inception b
4x inception c
1x inception d
2x inception e
1 conv_bn
1 adaptive pool 2d

dropout
flatten

fully connected layer

===================================
for our model, we are gonna just makeit smaller so that it trains faster, also cifar10 does not have the 1000 classes in imagenet lol
'''

class InceptionModel1(Module):
    def __init__(self, channels_in, class_num = 10):
        super(InceptionModel1, self).__init__()
        # remember, i must be able to extract the feature maps of each of the convolution layers, and as such, i must design my network around that as well

        # if this one is false, it will return feature maps. This would be found at the return funtion in the forward function
        self.PCA = False
        # input is N, 3, 32, 32
        self.layer1 = Sequential(
            Conv2d_BN(channels_in = channels_in, channels_out= 32, kernel_size=3, stride=2, padding=1),
            MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1)
             )
        # N, 32, 16, 16
        self.layer2 = Sequential(
            Conv2d_BN(channels_in = 32, channels_out= 64, kernel_size=3, stride=2, padding=1),
            MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1)
        )
        # N, 64, 8, 8

        # going into the inception layers
        # note that each of the components inside inception will ALWAYS retain the same width and height, and all the channels are concatenated together thats all
        self.incep1 = InceptionA(64, 16)
        # N, 240, 8, 8
        self.incep2 = InceptionB(240)
        # N, 720, 8, 8
        # inception 3 barely fits CIFAR10, i think this will be the last layer
        self.incep3 = InceptionC(720, 128)
        # N, 768, 8, 8
        self.incep4 = InceptionD(768)
        # N, 1280, 8, 8
        self.incep5 = InceptionE(1280)
        # N, 2048, 8, 8

        # going into the output layer now, last conv layer and then flattening it
        self.out = Sequential(
            # lowering the number of channels
            Conv2d_BN(channels_in = 2048, channels_out= 1024, kernel_size=1, stride=1, padding=0),
            AdaptiveAvgPool2d(1),
            Dropout(0.5)
        )
        # N, 1024, 1, 1

        # this one will then output it based on the number of classes, based on softmax i guess at this point
        self.fc = Linear(1024, class_num)

    def forward(self, x):
        x = self.layer1(x)
        fmap1 = x.clone()
        x = self.layer2(x)
        fmap2 = x.clone()
        x = self.incep1(x)
        fmap3 = x.clone()
        x = self.incep2(x)
        fmap4 = x.clone()
        x = self.incep3(x)
        fmap5 = x.clone()
        x = self.incep4(x)
        fmap6 = x.clone()
        x = self.incep5(x)
        fmap7 = x.clone()
        x = self.out(x)
        fmap8 = x.clone()
        # this one is to flatten, and retaining the batch size
        x = torch.flatten(x, 1)
        x = self.fc(x)
        fmap9 = x.clone()

        if self.PCA:
            return x, (fmap1, fmap2, fmap3, fmap3, fmap4, fmap5, fmap6, fmap7, fmap8, fmap9)
        else:
            return x

class InceptionModel2(Module):
    def __init__(self, channels_in, class_num = 10):
        super(InceptionModel2, self).__init__()
        # remember, i must be able to extract the feature maps of each of the convolution layers, and as such, i must design my network around that as well

        # if this one is false, it will return feature maps. This would be found at the return funtion in the forward function
        self.PCA = False
        # input is N, 3, 32, 32
        self.layer1 = Sequential(
            Conv2d_BN(channels_in = channels_in, channels_out= 32, kernel_size=3, stride=1, padding=1),
            MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1)
        )
        # N, 32, 16, 16
        self.layer2 = Sequential(
            Conv2d_BN(channels_in = 32, channels_out= 64, kernel_size=3, stride=1, padding=1),
            MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1)
        )
        # N, 64, 8, 8

        # going into the inception layers
        # note that each of the components inside inception will ALWAYS retain the same width and height, and all the channels are concatenated together thats all
        self.incep1 = InceptionA(64, 16)
        # N, 240, 8, 8
        self.incep2 = InceptionB(240)
        # N, 720, 8, 8
        # inception 3 barely fits CIFAR10, i think this will be the last layer
        self.incep3 = InceptionC(720, 128)
        # N, 768, 8, 8

        # going into the output layer now, last conv layer and then flattening it
        self.out = Sequential(
            # lowering the number of channels
            Conv2d_BN(channels_in = 768, channels_out= 320, kernel_size=1, stride=1, padding=0),
            AdaptiveAvgPool2d(1),
            Dropout(0.5)
        )
        # N, 1024, 1, 1

        # this one will then output it based on the number of classes, based on softmax i guess at this point
        self.fc = Linear(320, class_num)

    def forward(self, x):
        x = self.layer1(x)
        fmap1 = x.clone()
        x = self.layer2(x)
        fmap2 = x.clone()
        x = self.incep1(x)
        fmap3 = x.clone()
        x = self.incep2(x)
        fmap4 = x.clone()
        x = self.incep3(x)
        fmap5 = x.clone()
        x = self.out(x)
        fmap8 = x.clone()
        # this one is to flatten, and retaining the batch size
        x = torch.flatten(x, 1)
        x = self.fc(x)
        fmap9 = x.clone()

        if self.PCA:
            return x, (fmap1, fmap2, fmap3, fmap3, fmap4, fmap5, fmap8, fmap9)
        else:
            return x


# this is the intermediate modules
class Conv2d_BN(Module):
    def __init__(self, channels_in, channels_out, kernel_size, padding, stride=1, acti=LeakyReLU(0.2, inplace=True)):
        super(Conv2d_BN, self).__init__()
        self.conv2d_bn = Sequential(
            Conv2d(channels_in, channels_out, kernel_size, stride, padding, bias=False),
            BatchNorm2d(channels_out),
            acti
        )

    def forward(self, x):
        return self.conv2d_bn(x)

class InceptionA(Module):
    def __init__(self, channels_in, pool_channels):
        super(InceptionA, self).__init__()
        self.branch1x1 = Conv2d_BN(channels_in, 64, 1, stride=1, padding=0)  # 64 channels
        self.branch5x5 = Sequential(
            Conv2d_BN(channels_in, 48, 1, stride=1, padding=0),
            Conv2d_BN(48, 64, 5, stride=1, padding=2)
        )  # 64 channels
        self.branch3x3dbl = Sequential(
            Conv2d_BN(channels_in, 64, 1, stride=1, padding=0),
            Conv2d_BN(64, 96, 3, stride=1, padding=1),
            Conv2d_BN(96, 96, 3, stride=1, padding=1)
        )  # 96 channels
        self.branch_pool = Sequential(
            AvgPool2d(3, stride=1, padding=1),
            Conv2d_BN(channels_in, pool_channels, 1, stride=1, padding=0)
        )  # pool_channels

    def forward(self, x):
        outputs = [self.branch1x1(x), self.branch5x5(x), self.branch3x3dbl(x), self.branch_pool(x)]
        # 64 + 64 + 96 + pool_channels
        return torch.cat(outputs, 1)

class InceptionB(Module):
    def __init__(self, channels_in):
        super(InceptionB, self).__init__()
        self.branch3x3 = Conv2d_BN(channels_in, 384, 3, stride=2, padding=1)  # 384 channels
        self.branch3x3dbl = Sequential(
            Conv2d_BN(channels_in, 64, 1, padding=0),
            Conv2d_BN(64, 96, 3, padding=1),
            Conv2d_BN(96, 96, 3, stride=2, padding=1)
        )  # 96 channels
        self.branch_pool = MaxPool2d(3, stride=2, padding=1)  # channels_in

    def forward(self, x):
        outputs = [self.branch3x3(x), self.branch3x3dbl(x), self.branch_pool(x)]
        # 384 + 96 + channels_in
        return torch.cat(outputs, 1)

class InceptionC(Module):
    def __init__(self, channels_in, channels_7x7):
        super(InceptionC, self).__init__()
        self.branch1x1 = Conv2d_BN(channels_in, 192, 1, stride=1, padding=0)  # 192 channels
        self.branch7x7 = Sequential(
            Conv2d_BN(channels_in, channels_7x7, 1, stride=1, padding=0),
            Conv2d_BN(channels_7x7, channels_7x7, (1, 7), stride=1, padding=(0, 3)),
            Conv2d_BN(channels_7x7, 192, (7, 1), stride=1, padding=(3, 0))
        )  # 192 channels
        self.branch7x7dbl = Sequential(
            Conv2d_BN(channels_in, channels_7x7, 1, stride=1, padding=0),
            Conv2d_BN(channels_7x7, channels_7x7, (7, 1), stride=1, padding=(3, 0)),
            Conv2d_BN(channels_7x7, channels_7x7, (1, 7), stride=1, padding=(0, 3)),
            Conv2d_BN(channels_7x7, channels_7x7, (7, 1), stride=1, padding=(3, 0)),
            Conv2d_BN(channels_7x7, 192, (1, 7), stride=1, padding=(0, 3))
        )  # 192 channels
        self.branch_pool = Sequential(
            AvgPool2d(3, stride=1, padding=1),
            Conv2d_BN(channels_in, 192, 1, stride=1, padding=0)
        )  # 192 channels

    def forward(self, x):
        outputs = [self.branch1x1(x), self.branch7x7(x), self.branch7x7dbl(x), self.branch_pool(x)]
        # 192 + 192 + 192 + 192 = 768 channels
        return torch.cat(outputs, 1)

class InceptionD(Module):
    def __init__(self, channels_in):
        super(InceptionD, self).__init__()
        self.branch3x3 = Sequential(
            Conv2d_BN(channels_in, 192, 1, stride=1, padding=0),
            Conv2d_BN(192, 320, 3, stride=2, padding=1)
        )  # 320 channels
        self.branch7x7x3 = Sequential(
            Conv2d_BN(channels_in, 192, 1, stride=1, padding=0),
            Conv2d_BN(192, 192, (1, 7), stride=1, padding=(0, 3)),
            Conv2d_BN(192, 192, (7, 1), stride=1, padding=(3, 0)),
            Conv2d_BN(192, 192, 3, stride=2, padding=1)
        )  # 192 chnnels
        self.branch_pool = MaxPool2d(3, stride=2, padding=1)  # channels_in

    def forward(self, x):
        outputs = [self.branch3x3(x), self.branch7x7x3(x), self.branch_pool(x)]
        # 320 + 192 + channels_in
        return torch.cat(outputs, 1)

class InceptionE(Module):
    def __init__(self, channels_in):
        super(InceptionE, self).__init__()
        self.branch1x1 = Conv2d_BN(channels_in, 320, 1, stride=1, padding=0)  # 320 channels

        self.branch3x3_1 = Conv2d_BN(channels_in, 384, 1, stride=1, padding=0)
        self.branch3x3_2a = Conv2d_BN(384, 384, (1, 3), stride=1, padding=(0, 1))
        self.branch3x3_2b = Conv2d_BN(384, 384, (3, 1), stride=1, padding=(1, 0))
        # 768 channels

        self.branch3x3dbl_1 = Sequential(
            Conv2d_BN(channels_in, 448, 1, stride=1, padding=0),
            Conv2d_BN(448, 384, 3, stride=1, padding=1)
        )
        self.branch3x3dbl_2a = Conv2d_BN(384, 384, (1, 3), stride=1, padding=(0, 1))
        self.branch3x3dbl_2b = Conv2d_BN(384, 384, (3, 1), stride=1, padding=(1, 0))
        # 768 channels

        self.branch_pool = Sequential(
            AvgPool2d(3, stride=1, padding=1),
            Conv2d_BN(channels_in, 192, 1, stride=1, padding=0)
        )  # 192 channels
    def forward(self, x):
        branch1x1 = self.branch1x1(x)

        branch3x3 = self.branch3x3_1(x)
        branch3x3 = torch.cat([self.branch3x3_2a(branch3x3), self.branch3x3_2b(branch3x3)], 1)

        branch3x3dbl = self.branch3x3dbl_1(x)
        branch3x3dbl = torch.cat([self.branch3x3dbl_2a(branch3x3dbl), self.branch3x3dbl_2b(branch3x3dbl)], 1)

        branch_pool = self.branch_pool(x)

        outputs = [branch1x1, branch3x3, branch3x3dbl, branch_pool]
        # 320 + 768 + 768 + 192 = 2048 channels
        return torch.cat(outputs, 1)

# %%
# model = InceptionModel1(channels_in=3, class_num=10)
# print(summary(model, (64, 3, 32, 32)))

# %%
model = InceptionModel2(channels_in=3, class_num=10)
print(summary(model, (64, 3, 32, 32)))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# InceptionModel2                               [64, 10]                  --
# ├─Sequential: 1-1                             [64, 32, 16, 16]          --
# │    └─Conv2d_BN: 2-1                         [64, 32, 32, 32]          --
# │    │    └─Sequential: 3-1                   [64, 32, 32, 32]          928
# ├─Sequential: 1-49                            --                        (recursive)
# │    └─Conv2d_BN: 2-49                        --                        (recursive)
# │    │    └─Sequential: 3-48                  --                        (recursive)
# ├─Sequential: 1-3                             --                        (recursive)
# │    └─MaxPool2d: 2-3                         [64, 32, 16, 16]          --
# ├─Sequential: 1-4                             [64, 64, 8, 8]            --
# │    └─Conv2d_BN: 2-4                         [64, 64, 16, 16]          --
# │    │    └─Sequential: 3-3                   [64, 64, 16, 16]          18,560
# ├─Sequential: 1-49                            --                        (recursive)
# │    └─Conv2d_BN: 2-49                        --                        (recursive)
# │    │    └─Sequential: 3-48                  --                        (recursive)
# ├─Sequential: 1-6                             --                        (recursive)
# │    └─MaxPool2d: 2-6                         [64, 64, 8, 8]            --
# ├─InceptionA: 1-7                             [64, 240, 8, 8]           224,000
# │    └─Conv2d_BN: 2-7                         [64, 64, 8, 8]            --
# │    │    └─Sequential: 3-5                   [64, 64, 8, 8]            4,224
# ├─Sequential: 1-49                            --                        (recursive)
# │    └─Conv2d_BN: 2-49                        --                        (recursive)
# │    │    └─Sequential: 3-48                  --                        (recursive)
# ├─InceptionA: 1-19                            --                        (recursive)
# │    └─Sequential: 2-9                        [64, 64, 8, 8]            76,928
# │    │    └─Conv2d_BN: 3-7                    [64, 48, 8, 8]            3,168
# ├─Sequential: 1-49                            --                        (recursive)
# │    └─Conv2d_BN: 2-49                        --                        (recursive)
# │    │    └─Sequential: 3-48                  --                        (recursive)
# ├─InceptionA: 1-19                            --                        (recursive)
# │    └─Sequential: 2-11                       --                        (recursive)
# │    │    └─Conv2d_BN: 3-9                    [64, 64, 8, 8]            76,928
# ├─Sequential: 1-49                            --                        (recursive)
# │    └─Conv2d_BN: 2-49                        --                        (recursive)
# │    │    └─Sequential: 3-48                  --                        (recursive)
# ├─InceptionA: 1-19                            --                        (recursive)
# │    └─Sequential: 2-13                       [64, 96, 8, 8]            138,624
# │    │    └─Conv2d_BN: 3-11                   [64, 64, 8, 8]            4,224
# ├─Sequential: 1-49                            --                        (recursive)
# │    └─Conv2d_BN: 2-49                        --                        (recursive)
# │    │    └─Sequential: 3-48                  --                        (recursive)
# ├─InceptionA: 1-19                            --                        (recursive)
# │    └─Sequential: 2-17                       --                        (recursive)
# │    │    └─Conv2d_BN: 3-13                   [64, 96, 8, 8]            55,488
# ├─Sequential: 1-49                            --                        (recursive)
# │    └─Conv2d_BN: 2-49                        --                        (recursive)
# │    │    └─Sequential: 3-48                  --                        (recursive)
# ├─InceptionA: 1-19                            --                        (recursive)
# │    └─Sequential: 2-17                       --                        (recursive)
# │    │    └─Conv2d_BN: 3-15                   [64, 96, 8, 8]            83,136
# ├─Sequential: 1-49                            --                        (recursive)
# │    └─Conv2d_BN: 2-49                        --                        (recursive)
# │    │    └─Sequential: 3-48                  --                        (recursive)
# ├─InceptionA: 1-19                            --                        (recursive)
# │    └─Sequential: 2-19                       [64, 16, 8, 8]            --
# │    │    └─AvgPool2d: 3-17                   [64, 64, 8, 8]            --
# │    │    └─Conv2d_BN: 3-18                   [64, 16, 8, 8]            1,056
# ├─Sequential: 1-49                            --                        (recursive)
# │    └─Conv2d_BN: 2-49                        --                        (recursive)
# │    │    └─Sequential: 3-48                  --                        (recursive)
# ├─InceptionB: 1-21                            [64, 720, 4, 4]           154,112
# │    └─Conv2d_BN: 2-21                        [64, 384, 4, 4]           --
# │    │    └─Sequential: 3-20                  [64, 384, 4, 4]           830,208
# ├─Sequential: 1-49                            --                        (recursive)
# │    └─Conv2d_BN: 2-49                        --                        (recursive)
# │    │    └─Sequential: 3-48                  --                        (recursive)
# ├─InceptionB: 1-29                            --                        (recursive)
# │    └─Sequential: 2-23                       [64, 96, 4, 4]            138,624
# │    │    └─Conv2d_BN: 3-22                   [64, 64, 8, 8]            15,488
# ├─Sequential: 1-49                            --                        (recursive)
# │    └─Conv2d_BN: 2-49                        --                        (recursive)
# │    │    └─Sequential: 3-48                  --                        (recursive)
# ├─InceptionB: 1-29                            --                        (recursive)
# │    └─Sequential: 2-27                       --                        (recursive)
# │    │    └─Conv2d_BN: 3-24                   [64, 96, 8, 8]            55,488
# ├─Sequential: 1-49                            --                        (recursive)
# │    └─Conv2d_BN: 2-49                        --                        (recursive)
# │    │    └─Sequential: 3-48                  --                        (recursive)
# ├─InceptionB: 1-29                            --                        (recursive)
# │    └─Sequential: 2-27                       --                        (recursive)
# │    │    └─Conv2d_BN: 3-26                   [64, 96, 4, 4]            83,136
# ├─Sequential: 1-49                            --                        (recursive)
# │    └─Conv2d_BN: 2-49                        --                        (recursive)
# │    │    └─Sequential: 3-48                  --                        (recursive)
# ├─InceptionB: 1-29                            --                        (recursive)
# │    └─MaxPool2d: 2-29                        [64, 240, 4, 4]           --
# ├─InceptionC: 1-30                            [64, 768, 4, 4]           1,128,064
# │    └─Conv2d_BN: 2-30                        [64, 192, 4, 4]           --
# │    │    └─Sequential: 3-28                  [64, 192, 4, 4]           138,624
# ├─Sequential: 1-49                            --                        (recursive)
# │    └─Conv2d_BN: 2-49                        --                        (recursive)
# │    │    └─Sequential: 3-48                  --                        (recursive)
# ├─InceptionC: 1-48                            --                        (recursive)
# │    └─Sequential: 2-32                       [64, 192, 4, 4]           287,360
# │    │    └─Conv2d_BN: 3-30                   [64, 128, 4, 4]           92,416
# ├─Sequential: 1-49                            --                        (recursive)
# │    └─Conv2d_BN: 2-49                        --                        (recursive)
# │    │    └─Sequential: 3-48                  --                        (recursive)
# ├─InceptionC: 1-48                            --                        (recursive)
# │    └─Sequential: 2-36                       --                        (recursive)
# │    │    └─Conv2d_BN: 3-32                   [64, 128, 4, 4]           114,944
# ├─Sequential: 1-49                            --                        (recursive)
# │    └─Conv2d_BN: 2-49                        --                        (recursive)
# │    │    └─Sequential: 3-48                  --                        (recursive)
# ├─InceptionC: 1-48                            --                        (recursive)
# │    └─Sequential: 2-36                       --                        (recursive)
# │    │    └─Conv2d_BN: 3-34                   [64, 192, 4, 4]           172,416
# ├─Sequential: 1-49                            --                        (recursive)
# │    └─Conv2d_BN: 2-49                        --                        (recursive)
# │    │    └─Sequential: 3-48                  --                        (recursive)
# ├─InceptionC: 1-48                            --                        (recursive)
# │    └─Sequential: 2-38                       [64, 192, 4, 4]           517,248
# │    │    └─Conv2d_BN: 3-36                   [64, 128, 4, 4]           92,416
# ├─Sequential: 1-49                            --                        (recursive)
# │    └─Conv2d_BN: 2-49                        --                        (recursive)
# │    │    └─Sequential: 3-48                  --                        (recursive)
# ├─InceptionC: 1-48                            --                        (recursive)
# │    └─Sequential: 2-46                       --                        (recursive)
# │    │    └─Conv2d_BN: 3-38                   [64, 128, 4, 4]           114,944
# ├─Sequential: 1-49                            --                        (recursive)
# │    └─Conv2d_BN: 2-49                        --                        (recursive)
# │    │    └─Sequential: 3-48                  --                        (recursive)
# ├─InceptionC: 1-48                            --                        (recursive)
# │    └─Sequential: 2-46                       --                        (recursive)
# │    │    └─Conv2d_BN: 3-40                   [64, 128, 4, 4]           114,944
# ├─Sequential: 1-49                            --                        (recursive)
# │    └─Conv2d_BN: 2-49                        --                        (recursive)
# │    │    └─Sequential: 3-48                  --                        (recursive)
# ├─InceptionC: 1-48                            --                        (recursive)
# │    └─Sequential: 2-46                       --                        (recursive)
# │    │    └─Conv2d_BN: 3-42                   [64, 128, 4, 4]           114,944
# ├─Sequential: 1-49                            --                        (recursive)
# │    └─Conv2d_BN: 2-49                        --                        (recursive)
# │    │    └─Sequential: 3-48                  --                        (recursive)
# ├─InceptionC: 1-48                            --                        (recursive)
# │    └─Sequential: 2-46                       --                        (recursive)
# │    │    └─Conv2d_BN: 3-44                   [64, 192, 4, 4]           172,416
# ├─Sequential: 1-49                            --                        (recursive)
# │    └─Conv2d_BN: 2-49                        --                        (recursive)
# │    │    └─Sequential: 3-48                  --                        (recursive)
# ├─InceptionC: 1-48                            --                        (recursive)
# │    └─Sequential: 2-48                       [64, 192, 4, 4]           --
# │    │    └─AvgPool2d: 3-46                   [64, 720, 4, 4]           --
# │    │    └─Conv2d_BN: 3-47                   [64, 192, 4, 4]           138,624
# ├─Sequential: 1-49                            --                        (recursive)
# │    └─Conv2d_BN: 2-49                        --                        (recursive)
# │    │    └─Sequential: 3-48                  --                        (recursive)
# ├─Sequential: 1-50                            [64, 320, 1, 1]           --
# │    └─Conv2d_BN: 2-50                        [64, 320, 4, 4]           --
# │    │    └─Sequential: 3-49                  [64, 320, 4, 4]           246,400
# │    └─AdaptiveAvgPool2d: 2-51                [64, 320, 1, 1]           --
# │    └─Dropout: 2-52                          [64, 320, 1, 1]           --
# ├─Linear: 1-51                                [64, 10]                  3,210
# ===============================================================================================
# Total params: 5,413,290
# Trainable params: 5,413,290
# Non-trainable params: 0
# Total mult-adds (G): 4.06
# ===============================================================================================
# Input size (MB): 0.79
# Forward/backward pass size (MB): 128.46
# Params size (MB): 10.99
# Estimated Total Size (MB): 140.24
# ===============================================================================================

# %%
model.PCA = True
a, b = model.forward(torch.randn(64, 3, 32, 32).to('cuda'))

# %%
STUDENTID = 567     # this will be used for random states

import torch
import torchvision
import torchvision.transforms as transforms
import numpy as np
import logging
from utils import *
import torch.optim as optim
import os
import shutil
import os
import time

# Define data transformations
transform = transforms.Compose([
    transforms.ToTensor(),  # Convert PIL Image to PyTorch Tensor
    # this normalization is industry standard, it seems
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))  # Normalize the data
])


# define the label transformations, from int64 to float32
transform_label = transforms.Compose([
    #transforms.ToTensor()
])

# Download and load CIFAR-100 datasets
train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, transform=transform, download=True, target_transform=transform_label)
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, transform=transform, download=True, target_transform=transform_label)


# Calculate the sizes for train, validation, and test sets
train_size = int(0.8 * len(train_dataset))
valid_size = len(train_dataset) - train_size

# Split the train dataset into train and validation sets using a random seed
train_dataset, valid_dataset = torch.utils.data.random_split(train_dataset, [train_size, valid_size], generator=torch.Generator().manual_seed(STUDENTID))

# Create data loaders for training, validation, and test sets
batch_size = 64
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# Print dataset sizes
print("Number of training examples:", len(train_dataset))
print("Number of validation examples:", len(valid_dataset))
print("Number of test examples:", len(test_dataset))

# creating a model that automatically runs the forward function i guess, since it is easier
import torch
import torch.nn as nn
import torch.optim as optim
from utils import *
from customModels import *
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Number of training examples: 40000
# Number of validation examples: 10000
# Number of test examples: 10000

# %%
model = InceptionModel1(channels_in=3, class_num=10)
modelName = 'InceptionModel1_corect_data_aug'

argDict = {
    'lr': 0.001,
    'maxEpoch': 250,
    'idleEpoch': 25,
    'outputName': modelName,
    'optimizer': optim.SGD(model.parameters(), lr=0.001),
    'criterion': nn.CrossEntropyLoss()
}

# setting up the logger
loggerName = modelName + '.log'
loggerName = os.path.join(argDict['outputName'], loggerName)
logger = MyLogger(loggerName)
argDict['logger'] = logger

# just to initilalize the files
logger.log('training starts here')

start_time = time.time()

# training and saving model to dictionary
outputDict = train(model, argDict, train_loader, val_loader, test_loader)

# loading the best model, and then sending it off to testing
model = load_model_from_file(model, argDict['outputName'], argDict['outputName'])

test_accuracy = test(model, argDict, test_loader)
tempString = 'testing accuracy of ' + argDict['outputName'] + " is: " + str(test_accuracy)
logger.log(tempString)

argDict['test_accuracy'] = str(test_accuracy)

# timing the thing as well
end_time = time.time()
execution_time = end_time - start_time
argDict['time_taken'] = execution_time
save_dict_to_file(outputDict, argDict['outputName'], argDict['outputName'])

del model
del argDict

# Define the folder you want to zip and the output zip file name
folder_to_zip = modelName
output_zip_file = modelName + ".zip"

# Use shutil.make_archive to create the zip file
shutil.make_archive(output_zip_file, 'zip', folder_to_zip)

os.rename(output_zip_file + '.zip', output_zip_file)
# Out:
# training starts here
# currently at epoch 0 train accuracy: tensor(0.3019, device='cuda:0') loss of: 1.911883002090454 eval accuracy: tensor(0.3727, device='cuda:0')
# currently at epoch 1 train accuracy: tensor(0.4021, device='cuda:0') loss of: 1.6478466848373412 eval accuracy: tensor(0.4132, device='cuda:0')
# currently at epoch 2 train accuracy: tensor(0.4464, device='cuda:0') loss of: 1.5311889154434204 eval accuracy: tensor(0.4423, device='cuda:0')
# currently at epoch 3 train accuracy: tensor(0.4740, device='cuda:0') loss of: 1.4532343326568604 eval accuracy: tensor(0.4566, device='cuda:0')
# currently at epoch 4 train accuracy: tensor(0.5013, device='cuda:0') loss of: 1.3910504089355469 eval accuracy: tensor(0.4704, device='cuda:0')
# currently at epoch 5 train accuracy: tensor(0.5180, device='cuda:0') loss of: 1.3425525281906128 eval accuracy: tensor(0.4737, device='cuda:0')
# currently at epoch 6 train accuracy: tensor(0.5350, device='cuda:0') loss of: 1.2994744129180908 eval accuracy: tensor(0.4864, device='cuda:0')
# currently at epoch 7 train accuracy: tensor(0.5505, device='cuda:0') loss of: 1.2567621157646178 eval accuracy: tensor(0.4970, device='cuda:0')
# currently at epoch 8 train accuracy: tensor(0.5638, device='cuda:0') loss of: 1.2165677265167236 eval accuracy: tensor(0.4957, device='cuda:0')
# currently at epoch 9 train accuracy: tensor(0.5777, device='cuda:0') loss of: 1.1836685405731202 eval accuracy: tensor(0.4970, device='cuda:0')
# currently at epoch 10 train accuracy: tensor(0.5932, device='cuda:0') loss of: 1.149030516052246 eval accuracy: tensor(0.5005, device='cuda:0')
# currently at epoch 11 train accuracy: tensor(0.6039, device='cuda:0') loss of: 1.1108102336883545 eval accuracy: tensor(0.5013, device='cuda:0')
# currently at epoch 12 train accuracy: tensor(0.6131, device='cuda:0') loss of: 1.0849759024620056 eval accuracy: tensor(0.5112, device='cuda:0')
# currently at epoch 13 train accuracy: tensor(0.6253, device='cuda:0') loss of: 1.0532459167480468 eval accuracy: tensor(0.5070, device='cuda:0')
# currently at epoch 14 train accuracy: tensor(0.6365, device='cuda:0') loss of: 1.0204673426628112 eval accuracy: tensor(0.5035, device='cuda:0')
# currently at epoch 36 train accuracy: tensor(0.8262, device='cuda:0') loss of: 0.4876659201145172 eval accuracy: tensor(0.4985, device='cuda:0')
# currently at epoch 37 train accuracy: tensor(0.8278, device='cuda:0') loss of: 0.4848705101251602 eval accuracy: tensor(0.5060, device='cuda:0')
# currently at epoch 38 train accuracy: tensor(0.8397, device='cuda:0') loss of: 0.455162961268425 eval accuracy: tensor(0.5026, device='cuda:0')
# currently at epoch 39 train accuracy: tensor(0.8433, device='cuda:0') loss of: 0.4396078104019165 eval accuracy: tensor(0.5005, device='cuda:0')
# currently at epoch 40 train accuracy: tensor(0.8435, device='cuda:0') loss of: 0.4372215658664703 eval accuracy: tensor(0.5001, device='cuda:0')
# currently at epoch 41 train accuracy: tensor(0.8540, device='cuda:0') loss of: 0.413201331114769 eval accuracy: tensor(0.5031, device='cuda:0')
# currently at epoch 42 train accuracy: tensor(0.8593, device='cuda:0') loss of: 0.4029421724557877 eval accuracy: tensor(0.5022, device='cuda:0')
# currently at epoch 43 train accuracy: tensor(0.8611, device='cuda:0') loss of: 0.3896702229499817 eval accuracy: tensor(0.5085, device='cuda:0')
# currently at epoch 44 train accuracy: tensor(0.8644, device='cuda:0') loss of: 0.383201059627533 eval accuracy: tensor(0.4986, device='cuda:0')
# currently at epoch 45 train accuracy: tensor(0.8691, device='cuda:0') loss of: 0.3691086273193359 eval accuracy: tensor(0.4982, device='cuda:0')
# currently at epoch 46 train accuracy: tensor(0.8766, device='cuda:0') loss of: 0.3547241096496582 eval accuracy: tensor(0.5005, device='cuda:0')
# currently at epoch 47 train accuracy: tensor(0.8764, device='cuda:0') loss of: 0.35063884298801423 eval accuracy: tensor(0.4988, device='cuda:0')
# currently at epoch 48 train accuracy: tensor(0.8803, device='cuda:0') loss of: 0.3386729350090027 eval accuracy: tensor(0.5055, device='cuda:0')
# currently at epoch 49 train accuracy: tensor(0.8862, device='cuda:0') loss of: 0.32518335542678833 eval accuracy: tensor(0.4990, device='cuda:0')
# testing accuracy of InceptionModel1_corect_data_aug is: tensor(0.5160, device='cuda:0')

# %%
model = InceptionModel2(channels_in=3, class_num=10)
modelName = 'InceptionModel2_corect_data_aug'

argDict = {
    'lr': 0.001,
    'maxEpoch': 250,
    'idleEpoch': 25,
    'outputName': modelName,
    'optimizer': optim.SGD(model.parameters(), lr=0.001),
    'criterion': nn.CrossEntropyLoss()
}

# setting up the logger
loggerName = modelName + '.log'
loggerName = os.path.join(argDict['outputName'], loggerName)
logger = MyLogger(loggerName)
argDict['logger'] = logger

# just to initilalize the files
logger.log('training starts here')

start_time = time.time()

# training and saving model to dictionary
outputDict = train(model, argDict, train_loader, val_loader, test_loader)

# loading the best model, and then sending it off to testing
model = load_model_from_file(model, argDict['outputName'], argDict['outputName'])

test_accuracy = test(model, argDict, test_loader)
tempString = 'testing accuracy of ' + argDict['outputName'] + " is: " + str(test_accuracy)
logger.log(tempString)

argDict['test_accuracy'] = str(test_accuracy)

# timing the thing as well
end_time = time.time()
execution_time = end_time - start_time
argDict['time_taken'] = execution_time
save_dict_to_file(outputDict, argDict['outputName'], argDict['outputName'])

del model
del argDict

# Define the folder you want to zip and the output zip file name
folder_to_zip = modelName
output_zip_file = modelName + ".zip"

# Use shutil.make_archive to create the zip file
shutil.make_archive(output_zip_file, 'zip', folder_to_zip)

os.rename(output_zip_file + '.zip', output_zip_file)
# Out:
# training starts here
# currently at epoch 0 train accuracy: tensor(0.2759, device='cuda:0') loss of: 1.9911288063049317 eval accuracy: tensor(0.3407, device='cuda:0')
# currently at epoch 1 train accuracy: tensor(0.3696, device='cuda:0') loss of: 1.732855928993225 eval accuracy: tensor(0.3887, device='cuda:0')
# currently at epoch 2 train accuracy: tensor(0.4188, device='cuda:0') loss of: 1.6181901485443115 eval accuracy: tensor(0.4180, device='cuda:0')
# currently at epoch 3 train accuracy: tensor(0.4447, device='cuda:0') loss of: 1.5457998191833495 eval accuracy: tensor(0.4387, device='cuda:0')
# currently at epoch 4 train accuracy: tensor(0.4642, device='cuda:0') loss of: 1.4877448209762574 eval accuracy: tensor(0.4482, device='cuda:0')
# currently at epoch 5 train accuracy: tensor(0.4836, device='cuda:0') loss of: 1.4421364206314087 eval accuracy: tensor(0.4639, device='cuda:0')
# currently at epoch 6 train accuracy: tensor(0.4977, device='cuda:0') loss of: 1.4030528705596923 eval accuracy: tensor(0.4715, device='cuda:0')
# currently at epoch 7 train accuracy: tensor(0.5062, device='cuda:0') loss of: 1.3730973096847534 eval accuracy: tensor(0.4724, device='cuda:0')
# currently at epoch 8 train accuracy: tensor(0.5204, device='cuda:0') loss of: 1.337503625679016 eval accuracy: tensor(0.4814, device='cuda:0')
# currently at epoch 9 train accuracy: tensor(0.5307, device='cuda:0') loss of: 1.3068101287841798 eval accuracy: tensor(0.4901, device='cuda:0')
# currently at epoch 10 train accuracy: tensor(0.5424, device='cuda:0') loss of: 1.2849251253128051 eval accuracy: tensor(0.5000, device='cuda:0')
# currently at epoch 11 train accuracy: tensor(0.5510, device='cuda:0') loss of: 1.2571754079818727 eval accuracy: tensor(0.5020, device='cuda:0')
# currently at epoch 12 train accuracy: tensor(0.5579, device='cuda:0') loss of: 1.2408929095268248 eval accuracy: tensor(0.5061, device='cuda:0')
# currently at epoch 13 train accuracy: tensor(0.5709, device='cuda:0') loss of: 1.2142964977264403 eval accuracy: tensor(0.5069, device='cuda:0')
# currently at epoch 14 train accuracy: tensor(0.5762, device='cuda:0') loss of: 1.1921811463356018 eval accuracy: tensor(0.5101, device='cuda:0')
# currently at epoch 15 train accuracy: tensor(0.5850, device='cuda:0') loss of: 1.1705601167678834 eval accuracy: tensor(0.5128, device='cuda:0')
# currently at epoch 16 train accuracy: tensor(0.5933, device='cuda:0') loss of: 1.1492090448379517 eval accuracy: tensor(0.5152, device='cuda:0')
# currently at epoch 17 train accuracy: tensor(0.5971, device='cuda:0') loss of: 1.13218559551239 eval accuracy: tensor(0.5229, device='cuda:0')
# currently at epoch 18 train accuracy: tensor(0.6064, device='cuda:0') loss of: 1.1069786345481873 eval accuracy: tensor(0.5114, device='cuda:0')
# currently at epoch 41 train accuracy: tensor(0.7419, device='cuda:0') loss of: 0.7392080274105072 eval accuracy: tensor(0.5278, device='cuda:0')
# currently at epoch 42 train accuracy: tensor(0.7438, device='cuda:0') loss of: 0.7348470932483673 eval accuracy: tensor(0.5221, device='cuda:0')
# currently at epoch 43 train accuracy: tensor(0.7429, device='cuda:0') loss of: 0.7295140357494354 eval accuracy: tensor(0.5229, device='cuda:0')
# currently at epoch 44 train accuracy: tensor(0.7523, device='cuda:0') loss of: 0.7069166626930237 eval accuracy: tensor(0.5268, device='cuda:0')
# currently at epoch 45 train accuracy: tensor(0.7559, device='cuda:0') loss of: 0.699727451467514 eval accuracy: tensor(0.5231, device='cuda:0')
# currently at epoch 46 train accuracy: tensor(0.7581, device='cuda:0') loss of: 0.6878946505069733 eval accuracy: tensor(0.5211, device='cuda:0')
# currently at epoch 47 train accuracy: tensor(0.7652, device='cuda:0') loss of: 0.6719631301403046 eval accuracy: tensor(0.5194, device='cuda:0')
# currently at epoch 48 train accuracy: tensor(0.7703, device='cuda:0') loss of: 0.6589432964801788 eval accuracy: tensor(0.5204, device='cuda:0')
# currently at epoch 49 train accuracy: tensor(0.7706, device='cuda:0') loss of: 0.6518875275611877 eval accuracy: tensor(0.5182, device='cuda:0')
# currently at epoch 50 train accuracy: tensor(0.7721, device='cuda:0') loss of: 0.6425373195648193 eval accuracy: tensor(0.5173, device='cuda:0')
# currently at epoch 51 train accuracy: tensor(0.7781, device='cuda:0') loss of: 0.6315002954006195 eval accuracy: tensor(0.5202, device='cuda:0')
# currently at epoch 52 train accuracy: tensor(0.7862, device='cuda:0') loss of: 0.6109196265220642 eval accuracy: tensor(0.5220, device='cuda:0')
# currently at epoch 53 train accuracy: tensor(0.7874, device='cuda:0') loss of: 0.6023323187828064 eval accuracy: tensor(0.5226, device='cuda:0')
# currently at epoch 54 train accuracy: tensor(0.7906, device='cuda:0') loss of: 0.5904496984958648 eval accuracy: tensor(0.5241, device='cuda:0')
# currently at epoch 55 train accuracy: tensor(0.7919, device='cuda:0') loss of: 0.5915850285053253 eval accuracy: tensor(0.5225, device='cuda:0')
# currently at epoch 56 train accuracy: tensor(0.7984, device='cuda:0') loss of: 0.5729072989463806 eval accuracy: tensor(0.5247, device='cuda:0')
# currently at epoch 57 train accuracy: tensor(0.8034, device='cuda:0') loss of: 0.5633375228404999 eval accuracy: tensor(0.5149, device='cuda:0')
# currently at epoch 58 train accuracy: tensor(0.8083, device='cuda:0') loss of: 0.5520967173576355 eval accuracy: tensor(0.5148, device='cuda:0')
# currently at epoch 59 train accuracy: tensor(0.8080, device='cuda:0') loss of: 0.545767864894867 eval accuracy: tensor(0.5161, device='cuda:0')
# currently at epoch 60 train accuracy: tensor(0.8117, device='cuda:0') loss of: 0.538718496632576 eval accuracy: tensor(0.5216, device='cuda:0')
# testing accuracy of InceptionModel2_corect_data_aug is: tensor(0.5316, device='cuda:0')

# %%
model = InceptionModel2(channels_in=3, class_num=10)
modelName = 'InceptionModel2_data_aug_cropping'

# this transformation sequence must be modified to work with the random stuff
# Define data transformations
transform = transforms.Compose([
    transforms.ToTensor(),  # Convert PIL Image to PyTorch Tensor
    # this normalization is industry standard, it seems
    transforms.RandomCrop(size=28, padding=2, pad_if_needed=True, padding_mode="edge"),
    transforms.Resize(32),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))  # Normalize the data
])

argDict = {
    'lr': 0.001,
    'maxEpoch': 250,
    'idleEpoch': 25,
    'outputName': modelName,
    'optimizer': optim.SGD(model.parameters(), lr=0.001),
    'criterion': nn.CrossEntropyLoss()
}

STUDENTID = 567     # this will be used for random states

import torch
import torchvision
import torchvision.transforms as transforms
import numpy as np
import logging
from utils import *
import torch.optim as optim
import os
import shutil
import os
import time


# define the label transformations, from int64 to float32
transform_label = transforms.Compose([
    #transforms.ToTensor()
])

# Download and load CIFAR-100 datasets
train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, transform=transform, download=True, target_transform=transform_label)
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, transform=transform, download=True, target_transform=transform_label)


# Calculate the sizes for train, validation, and test sets
train_size = int(0.8 * len(train_dataset))
valid_size = len(train_dataset) - train_size

# Split the train dataset into train and validation sets using a random seed
train_dataset, valid_dataset = torch.utils.data.random_split(train_dataset, [train_size, valid_size], generator=torch.Generator().manual_seed(STUDENTID))

# Create data loaders for training, validation, and test sets
batch_size = 64
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# Print dataset sizes
print("Number of training examples:", len(train_dataset))
print("Number of validation examples:", len(valid_dataset))
print("Number of test examples:", len(test_dataset))

# creating a model that automatically runs the forward function i guess, since it is easier
import torch
import torch.nn as nn
import torch.optim as optim
from utils import *
from customModels import *

# setting up the logger
loggerName = modelName + '.log'
loggerName = os.path.join(argDict['outputName'], loggerName)
logger = MyLogger(loggerName)
argDict['logger'] = logger

# just to initilalize the files
logger.log('training starts here')

start_time = time.time()

# training and saving model to dictionary
outputDict = train(model, argDict, train_loader, val_loader, test_loader)

# loading the best model, and then sending it off to testing
model = load_model_from_file(model, argDict['outputName'], argDict['outputName'])

test_accuracy = test(model, argDict, test_loader)
tempString = 'testing accuracy of ' + argDict['outputName'] + " is: " + str(test_accuracy)
logger.log(tempString)

argDict['test_accuracy'] = str(test_accuracy)

# timing the thing as well
end_time = time.time()
execution_time = end_time - start_time
argDict['time_taken'] = execution_time
save_dict_to_file(outputDict, argDict['outputName'], argDict['outputName'])

del model
del argDict

# Define the folder you want to zip and the output zip file name
folder_to_zip = modelName
output_zip_file = modelName + ".zip"

# Use shutil.make_archive to create the zip file
shutil.make_archive(output_zip_file, 'zip', folder_to_zip)

os.rename(output_zip_file + '.zip', output_zip_file)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Number of training examples: 40000
# Number of validation examples: 10000
# Number of test examples: 10000
# training starts here
# currently at epoch 0 train accuracy: tensor(0.2651, device='cuda:0') loss of: 1.9998745420455932 eval accuracy: tensor(0.3115, device='cuda:0')
# currently at epoch 1 train accuracy: tensor(0.3394, device='cuda:0') loss of: 1.7993052368164062 eval accuracy: tensor(0.3529, device='cuda:0')
# currently at epoch 2 train accuracy: tensor(0.3741, device='cuda:0') loss of: 1.717935894393921 eval accuracy: tensor(0.3789, device='cuda:0')
# currently at epoch 3 train accuracy: tensor(0.3968, device='cuda:0') loss of: 1.662701590538025 eval accuracy: tensor(0.3962, device='cuda:0')
# currently at epoch 240 train accuracy: tensor(0.7076, device='cuda:0') loss of: 0.8280668162345887 eval accuracy: tensor(0.6062, device='cuda:0')
# currently at epoch 241 train accuracy: tensor(0.7040, device='cuda:0') loss of: 0.833104518032074 eval accuracy: tensor(0.5983, device='cuda:0')
# currently at epoch 242 train accuracy: tensor(0.7058, device='cuda:0') loss of: 0.8286026713371277 eval accuracy: tensor(0.6014, device='cuda:0')
# currently at epoch 243 train accuracy: tensor(0.7054, device='cuda:0') loss of: 0.8294823764801026 eval accuracy: tensor(0.6054, device='cuda:0')
# currently at epoch 244 train accuracy: tensor(0.7030, device='cuda:0') loss of: 0.8297519199848175 eval accuracy: tensor(0.5990, device='cuda:0')
# currently at epoch 245 train accuracy: tensor(0.7088, device='cuda:0') loss of: 0.8203996453762055 eval accuracy: tensor(0.6047, device='cuda:0')
# currently at epoch 246 train accuracy: tensor(0.7071, device='cuda:0') loss of: 0.8270306494235993 eval accuracy: tensor(0.6055, device='cuda:0')
# currently at epoch 247 train accuracy: tensor(0.7066, device='cuda:0') loss of: 0.8233772599697113 eval accuracy: tensor(0.6029, device='cuda:0')
# currently at epoch 248 train accuracy: tensor(0.7105, device='cuda:0') loss of: 0.8232044990062714 eval accuracy: tensor(0.6015, device='cuda:0')
# currently at epoch 249 train accuracy: tensor(0.7119, device='cuda:0') loss of: 0.8203260826587677 eval accuracy: tensor(0.6067, device='cuda:0')
# testing accuracy of InceptionModel2_data_aug_cropping is: tensor(0.6013, device='cuda:0')

# %%
model = InceptionModel2(channels_in=3, class_num=10)
modelName = 'InceptionModel2_data_aug_flip'

# this transformation sequence must be modified to work with the random stuff
# Define data transformations
transform = transforms.Compose([
    transforms.ToTensor(),  # Convert PIL Image to PyTorch Tensor
    # this normalization is industry standard, it seems
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.5),
    transforms.Resize(32),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))  # Normalize the data
])

argDict = {
    'lr': 0.001,
    'maxEpoch': 250,
    'idleEpoch': 25,
    'outputName': modelName,
    'optimizer': optim.SGD(model.parameters(), lr=0.001),
    'criterion': nn.CrossEntropyLoss()
}

STUDENTID = 567     # this will be used for random states

import torch
import torchvision
import torchvision.transforms as transforms
import numpy as np
import logging
from utils import *
import torch.optim as optim
import os
import shutil
import os
import time


# define the label transformations, from int64 to float32
transform_label = transforms.Compose([
    #transforms.ToTensor()
])

# Download and load CIFAR-100 datasets
train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, transform=transform, download=True, target_transform=transform_label)
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, transform=transform, download=True, target_transform=transform_label)


# Calculate the sizes for train, validation, and test sets
train_size = int(0.8 * len(train_dataset))
valid_size = len(train_dataset) - train_size

# Split the train dataset into train and validation sets using a random seed
train_dataset, valid_dataset = torch.utils.data.random_split(train_dataset, [train_size, valid_size], generator=torch.Generator().manual_seed(STUDENTID))

# Create data loaders for training, validation, and test sets
batch_size = 64
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# Print dataset sizes
print("Number of training examples:", len(train_dataset))
print("Number of validation examples:", len(valid_dataset))
print("Number of test examples:", len(test_dataset))

# creating a model that automatically runs the forward function i guess, since it is easier
import torch
import torch.nn as nn
import torch.optim as optim
from utils import *
from customModels import *

# setting up the logger
loggerName = modelName + '.log'
loggerName = os.path.join(argDict['outputName'], loggerName)
logger = MyLogger(loggerName)
argDict['logger'] = logger

# just to initilalize the files
logger.log('training starts here')

start_time = time.time()

# training and saving model to dictionary
outputDict = train(model, argDict, train_loader, val_loader, test_loader)

# loading the best model, and then sending it off to testing
model = load_model_from_file(model, argDict['outputName'], argDict['outputName'])

test_accuracy = test(model, argDict, test_loader)
tempString = 'testing accuracy of ' + argDict['outputName'] + " is: " + str(test_accuracy)
logger.log(tempString)

argDict['test_accuracy'] = str(test_accuracy)

# timing the thing as well
end_time = time.time()
execution_time = end_time - start_time
argDict['time_taken'] = execution_time
save_dict_to_file(outputDict, argDict['outputName'], argDict['outputName'])

del model
del argDict

# Define the folder you want to zip and the output zip file name
folder_to_zip = modelName
output_zip_file = modelName + ".zip"

# Use shutil.make_archive to create the zip file
shutil.make_archive(output_zip_file, 'zip', folder_to_zip)

os.rename(output_zip_file + '.zip', output_zip_file)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Number of training examples: 40000
# Number of validation examples: 10000
# Number of test examples: 10000
# training starts here
# currently at epoch 0 train accuracy: tensor(0.2536, device='cuda:0') loss of: 2.039087518501282 eval accuracy: tensor(0.3123, device='cuda:0')
# currently at epoch 1 train accuracy: tensor(0.3392, device='cuda:0') loss of: 1.8063823118209839 eval accuracy: tensor(0.3582, device='cuda:0')
# currently at epoch 2 train accuracy: tensor(0.3709, device='cuda:0') loss of: 1.7219138929367066 eval accuracy: tensor(0.3760, device='cuda:0')
# currently at epoch 3 train accuracy: tensor(0.3946, device='cuda:0') loss of: 1.6668205379486083 eval accuracy: tensor(0.3927, device='cuda:0')
# currently at epoch 4 train accuracy: tensor(0.4090, device='cuda:0') loss of: 1.6224696214675904 eval accuracy: tensor(0.4104, device='cuda:0')
# currently at epoch 5 train accuracy: tensor(0.4232, device='cuda:0') loss of: 1.5888654586791993 eval accuracy: tensor(0.4274, device='cuda:0')
# currently at epoch 6 train accuracy: tensor(0.4355, device='cuda:0') loss of: 1.5541200317382813 eval accuracy: tensor(0.4296, device='cuda:0')
# currently at epoch 7 train accuracy: tensor(0.4516, device='cuda:0') loss of: 1.5207333061218262 eval accuracy: tensor(0.4311, device='cuda:0')
# currently at epoch 8 train accuracy: tensor(0.4570, device='cuda:0') loss of: 1.5009328681945802 eval accuracy: tensor(0.4545, device='cuda:0')
# currently at epoch 9 train accuracy: tensor(0.4681, device='cuda:0') loss of: 1.477684068775177 eval accuracy: tensor(0.4596, device='cuda:0')
# currently at epoch 10 train accuracy: tensor(0.4749, device='cuda:0') loss of: 1.4595302703857422 eval accuracy: tensor(0.4607, device='cuda:0')
# currently at epoch 11 train accuracy: tensor(0.4803, device='cuda:0') loss of: 1.4399176916122436 eval accuracy: tensor(0.4643, device='cuda:0')
# currently at epoch 12 train accuracy: tensor(0.4856, device='cuda:0') loss of: 1.429245018196106 eval accuracy: tensor(0.4712, device='cuda:0')
# currently at epoch 13 train accuracy: tensor(0.4941, device='cuda:0') loss of: 1.4074470567703248 eval accuracy: tensor(0.4774, device='cuda:0')
# currently at epoch 14 train accuracy: tensor(0.4989, device='cuda:0') loss of: 1.3935443577766418 eval accuracy: tensor(0.4791, device='cuda:0')
# currently at epoch 123 train accuracy: tensor(0.6872, device='cuda:0') loss of: 0.8815671235084533 eval accuracy: tensor(0.5766, device='cuda:0')
# currently at epoch 124 train accuracy: tensor(0.6865, device='cuda:0') loss of: 0.8834228120803833 eval accuracy: tensor(0.5781, device='cuda:0')
# currently at epoch 125 train accuracy: tensor(0.6892, device='cuda:0') loss of: 0.8700977075576782 eval accuracy: tensor(0.5765, device='cuda:0')
# currently at epoch 126 train accuracy: tensor(0.6892, device='cuda:0') loss of: 0.8748055749893189 eval accuracy: tensor(0.5816, device='cuda:0')
# currently at epoch 127 train accuracy: tensor(0.6891, device='cuda:0') loss of: 0.874452075099945 eval accuracy: tensor(0.5707, device='cuda:0')
# currently at epoch 128 train accuracy: tensor(0.6922, device='cuda:0') loss of: 0.8665386080741883 eval accuracy: tensor(0.5753, device='cuda:0')
# currently at epoch 129 train accuracy: tensor(0.6890, device='cuda:0') loss of: 0.8690181458473205 eval accuracy: tensor(0.5739, device='cuda:0')
# testing accuracy of InceptionModel2_data_aug_flip is: tensor(0.5739, device='cuda:0')

# %%
model = InceptionModel2(channels_in=3, class_num=10)
modelName = 'InceptionModel2_data_aug_rotation'

# this transformation sequence must be modified to work with the random stuff
# Define data transformations
transform = transforms.Compose([
    transforms.ToTensor(),  # Convert PIL Image to PyTorch Tensor
    # this normalization is industry standard, it seems
    transforms.RandomRotation(360),
    transforms.Resize(32),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))  # Normalize the data
])

argDict = {
    'lr': 0.001,
    'maxEpoch': 250,
    'idleEpoch': 25,
    'outputName': modelName,
    'optimizer': optim.SGD(model.parameters(), lr=0.001),
    'criterion': nn.CrossEntropyLoss()
}

STUDENTID = 567     # this will be used for random states

import torch
import torchvision
import torchvision.transforms as transforms
import numpy as np
import logging
from utils import *
import torch.optim as optim
import os
import shutil
import os
import time


# define the label transformations, from int64 to float32
transform_label = transforms.Compose([
    #transforms.ToTensor()
])

# Download and load CIFAR-100 datasets
train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, transform=transform, download=True, target_transform=transform_label)
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, transform=transform, download=True, target_transform=transform_label)


# Calculate the sizes for train, validation, and test sets
train_size = int(0.8 * len(train_dataset))
valid_size = len(train_dataset) - train_size

# Split the train dataset into train and validation sets using a random seed
train_dataset, valid_dataset = torch.utils.data.random_split(train_dataset, [train_size, valid_size], generator=torch.Generator().manual_seed(STUDENTID))

# Create data loaders for training, validation, and test sets
batch_size = 64
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# Print dataset sizes
print("Number of training examples:", len(train_dataset))
print("Number of validation examples:", len(valid_dataset))
print("Number of test examples:", len(test_dataset))

# creating a model that automatically runs the forward function i guess, since it is easier
import torch
import torch.nn as nn
import torch.optim as optim
from utils import *
from customModels import *

# setting up the logger
loggerName = modelName + '.log'
loggerName = os.path.join(argDict['outputName'], loggerName)
logger = MyLogger(loggerName)
argDict['logger'] = logger

# just to initilalize the files
logger.log('training starts here')

start_time = time.time()

# training and saving model to dictionary
outputDict = train(model, argDict, train_loader, val_loader, test_loader)

# loading the best model, and then sending it off to testing
model = load_model_from_file(model, argDict['outputName'], argDict['outputName'])

test_accuracy = test(model, argDict, test_loader)
tempString = 'testing accuracy of ' + argDict['outputName'] + " is: " + str(test_accuracy)
logger.log(tempString)

argDict['test_accuracy'] = str(test_accuracy)

# timing the thing as well
end_time = time.time()
execution_time = end_time - start_time
argDict['time_taken'] = execution_time
save_dict_to_file(outputDict, argDict['outputName'], argDict['outputName'])

del model
del argDict

# Define the folder you want to zip and the output zip file name
folder_to_zip = modelName
output_zip_file = modelName + ".zip"

# Use shutil.make_archive to create the zip file
shutil.make_archive(output_zip_file, 'zip', folder_to_zip)

os.rename(output_zip_file + '.zip', output_zip_file)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Number of training examples: 40000
# Number of validation examples: 10000
# Number of test examples: 10000
# training starts here
# currently at epoch 0 train accuracy: tensor(0.2351, device='cuda:0') loss of: 2.0827041969299316 eval accuracy: tensor(0.2755, device='cuda:0')
# currently at epoch 1 train accuracy: tensor(0.2947, device='cuda:0') loss of: 1.9207049633026123 eval accuracy: tensor(0.3028, device='cuda:0')
# currently at epoch 2 train accuracy: tensor(0.3159, device='cuda:0') loss of: 1.859469598388672 eval accuracy: tensor(0.3275, device='cuda:0')
# currently at epoch 3 train accuracy: tensor(0.3316, device='cuda:0') loss of: 1.8144521184921265 eval accuracy: tensor(0.3394, device='cuda:0')
# currently at epoch 4 train accuracy: tensor(0.3460, device='cuda:0') loss of: 1.7829607051849365 eval accuracy: tensor(0.3558, device='cuda:0')
# currently at epoch 5 train accuracy: tensor(0.3600, device='cuda:0') loss of: 1.7555461103439332 eval accuracy: tensor(0.3691, device='cuda:0')
# currently at epoch 6 train accuracy: tensor(0.3677, device='cuda:0') loss of: 1.7344105993270873 eval accuracy: tensor(0.3709, device='cuda:0')
# currently at epoch 7 train accuracy: tensor(0.3792, device='cuda:0') loss of: 1.7137888927459717 eval accuracy: tensor(0.3801, device='cuda:0')
# currently at epoch 8 train accuracy: tensor(0.3853, device='cuda:0') loss of: 1.6951598388671876 eval accuracy: tensor(0.3857, device='cuda:0')
# currently at epoch 9 train accuracy: tensor(0.3919, device='cuda:0') loss of: 1.6803249313354491 eval accuracy: tensor(0.3926, device='cuda:0')
# currently at epoch 10 train accuracy: tensor(0.3956, device='cuda:0') loss of: 1.6665543235778808 eval accuracy: tensor(0.3984, device='cuda:0')
# currently at epoch 11 train accuracy: tensor(0.4003, device='cuda:0') loss of: 1.6535699296951294 eval accuracy: tensor(0.3996, device='cuda:0')
# currently at epoch 12 train accuracy: tensor(0.4082, device='cuda:0') loss of: 1.6388052431106568 eval accuracy: tensor(0.4031, device='cuda:0')
# currently at epoch 13 train accuracy: tensor(0.4104, device='cuda:0') loss of: 1.633256785774231 eval accuracy: tensor(0.4042, device='cuda:0')
# currently at epoch 14 train accuracy: tensor(0.4156, device='cuda:0') loss of: 1.6252216995239257 eval accuracy: tensor(0.4148, device='cuda:0')
# currently at epoch 15 train accuracy: tensor(0.4158, device='cuda:0') loss of: 1.6168407556533813 eval accuracy: tensor(0.4102, device='cuda:0')
# currently at epoch 16 train accuracy: tensor(0.4188, device='cuda:0') loss of: 1.6101091735839843 eval accuracy: tensor(0.4148, device='cuda:0')
# currently at epoch 125 train accuracy: tensor(0.5553, device='cuda:0') loss of: 1.242941660308838 eval accuracy: tensor(0.5062, device='cuda:0')
# currently at epoch 126 train accuracy: tensor(0.5565, device='cuda:0') loss of: 1.2455082220077516 eval accuracy: tensor(0.5112, device='cuda:0')
# currently at epoch 127 train accuracy: tensor(0.5554, device='cuda:0') loss of: 1.2452850368499755 eval accuracy: tensor(0.5030, device='cuda:0')
# currently at epoch 128 train accuracy: tensor(0.5583, device='cuda:0') loss of: 1.2369354299545288 eval accuracy: tensor(0.5104, device='cuda:0')
# currently at epoch 129 train accuracy: tensor(0.5570, device='cuda:0') loss of: 1.2420335720062257 eval accuracy: tensor(0.5122, device='cuda:0')
# currently at epoch 130 train accuracy: tensor(0.5595, device='cuda:0') loss of: 1.2363762639045714 eval accuracy: tensor(0.5119, device='cuda:0')
# currently at epoch 131 train accuracy: tensor(0.5588, device='cuda:0') loss of: 1.236850782585144 eval accuracy: tensor(0.5091, device='cuda:0')
# currently at epoch 132 train accuracy: tensor(0.5579, device='cuda:0') loss of: 1.2327567417144776 eval accuracy: tensor(0.5104, device='cuda:0')
# currently at epoch 133 train accuracy: tensor(0.5618, device='cuda:0') loss of: 1.2316367091178895 eval accuracy: tensor(0.5041, device='cuda:0')
# currently at epoch 134 train accuracy: tensor(0.5583, device='cuda:0') loss of: 1.2368581265449523 eval accuracy: tensor(0.5132, device='cuda:0')
# testing accuracy of InceptionModel2_data_aug_rotation is: tensor(0.5000, device='cuda:0')

# %%
model = InceptionModel2(channels_in=3, class_num=10)
modelName = 'InceptionModel2_data_aug_reiszeCrop'

# this transformation sequence must be modified to work with the random stuff
# Define data transformations
transform = transforms.Compose([
    transforms.ToTensor(),  # Convert PIL Image to PyTorch Tensor
    # this normalization is industry standard, it seems
    transforms.RandomResizedCrop(size=32),
    transforms.Resize(32),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))  # Normalize the data
])

argDict = {
    'lr': 0.001,
    'maxEpoch': 250,
    'idleEpoch': 25,
    'outputName': modelName,
    'optimizer': optim.SGD(model.parameters(), lr=0.001),
    'criterion': nn.CrossEntropyLoss()
}

STUDENTID = 567     # this will be used for random states

import torch
import torchvision
import torchvision.transforms as transforms
import numpy as np
import logging
from utils import *
import torch.optim as optim
import os
import shutil
import os
import time


# define the label transformations, from int64 to float32
transform_label = transforms.Compose([
    #transforms.ToTensor()
])

# Download and load CIFAR-100 datasets
train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, transform=transform, download=True, target_transform=transform_label)
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, transform=transform, download=True, target_transform=transform_label)


# Calculate the sizes for train, validation, and test sets
train_size = int(0.8 * len(train_dataset))
valid_size = len(train_dataset) - train_size

# Split the train dataset into train and validation sets using a random seed
train_dataset, valid_dataset = torch.utils.data.random_split(train_dataset, [train_size, valid_size], generator=torch.Generator().manual_seed(STUDENTID))

# Create data loaders for training, validation, and test sets
batch_size = 64
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# Print dataset sizes
print("Number of training examples:", len(train_dataset))
print("Number of validation examples:", len(valid_dataset))
print("Number of test examples:", len(test_dataset))

# creating a model that automatically runs the forward function i guess, since it is easier
import torch
import torch.nn as nn
import torch.optim as optim
from utils import *
from customModels import *

# setting up the logger
loggerName = modelName + '.log'
loggerName = os.path.join(argDict['outputName'], loggerName)
logger = MyLogger(loggerName)
argDict['logger'] = logger

# just to initilalize the files
logger.log('training starts here')

start_time = time.time()

# training and saving model to dictionary
outputDict = train(model, argDict, train_loader, val_loader, test_loader)

# loading the best model, and then sending it off to testing
model = load_model_from_file(model, argDict['outputName'], argDict['outputName'])

test_accuracy = test(model, argDict, test_loader)
tempString = 'testing accuracy of ' + argDict['outputName'] + " is: " + str(test_accuracy)
logger.log(tempString)

argDict['test_accuracy'] = str(test_accuracy)

# timing the thing as well
end_time = time.time()
execution_time = end_time - start_time
argDict['time_taken'] = execution_time
save_dict_to_file(outputDict, argDict['outputName'], argDict['outputName'])

del model
del argDict

# Define the folder you want to zip and the output zip file name
folder_to_zip = modelName
output_zip_file = modelName + ".zip"

# Use shutil.make_archive to create the zip file
shutil.make_archive(output_zip_file, 'zip', folder_to_zip)

os.rename(output_zip_file + '.zip', output_zip_file)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Number of training examples: 40000
# Number of validation examples: 10000
# Number of test examples: 10000
# training starts here
# currently at epoch 0 train accuracy: tensor(0.2314, device='cuda:0') loss of: 2.078931097984314 eval accuracy: tensor(0.2701, device='cuda:0')
# currently at epoch 1 train accuracy: tensor(0.2887, device='cuda:0') loss of: 1.9303240478515624 eval accuracy: tensor(0.3025, device='cuda:0')
# currently at epoch 2 train accuracy: tensor(0.3093, device='cuda:0') loss of: 1.874745209121704 eval accuracy: tensor(0.3299, device='cuda:0')
# currently at epoch 3 train accuracy: tensor(0.3272, device='cuda:0') loss of: 1.8353795532226562 eval accuracy: tensor(0.3334, device='cuda:0')
# currently at epoch 4 train accuracy: tensor(0.3444, device='cuda:0') loss of: 1.7983158248901367 eval accuracy: tensor(0.3466, device='cuda:0')
# currently at epoch 5 train accuracy: tensor(0.3518, device='cuda:0') loss of: 1.7808175567626954 eval accuracy: tensor(0.3568, device='cuda:0')
# currently at epoch 6 train accuracy: tensor(0.3611, device='cuda:0') loss of: 1.7577114305496215 eval accuracy: tensor(0.3640, device='cuda:0')
# currently at epoch 7 train accuracy: tensor(0.3671, device='cuda:0') loss of: 1.742117326927185 eval accuracy: tensor(0.3730, device='cuda:0')
# currently at epoch 8 train accuracy: tensor(0.3775, device='cuda:0') loss of: 1.721692914390564 eval accuracy: tensor(0.3801, device='cuda:0')
# currently at epoch 9 train accuracy: tensor(0.3817, device='cuda:0') loss of: 1.7115679811477662 eval accuracy: tensor(0.3829, device='cuda:0')
# currently at epoch 10 train accuracy: tensor(0.3874, device='cuda:0') loss of: 1.6871027467727662 eval accuracy: tensor(0.3847, device='cuda:0')
# currently at epoch 11 train accuracy: tensor(0.3963, device='cuda:0') loss of: 1.6765242368698121 eval accuracy: tensor(0.3906, device='cuda:0')
# currently at epoch 12 train accuracy: tensor(0.3965, device='cuda:0') loss of: 1.6689916961669922 eval accuracy: tensor(0.3838, device='cuda:0')
# currently at epoch 13 train accuracy: tensor(0.4002, device='cuda:0') loss of: 1.6643321105957032 eval accuracy: tensor(0.3980, device='cuda:0')
