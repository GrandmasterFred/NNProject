# %% [markdown]
#  # this file will try to trian the two models defined here. And determine which is the best performing one

# %%
from torch.nn import Module, Sequential, LeakyReLU, Conv2d, BatchNorm2d, AvgPool2d, MaxPool2d, AdaptiveAvgPool2d, Linear, Dropout
import torch
from torchinfo import summary

# this is adapted from https://github.com/Moeo3/GoogLeNet-Inception-V3-pytorch/blob/master/googlenet_v3.py#L58 with its size modified to suit the CIFAR10 dataset instead of the origianl ImageNet dataset.

''' comments on models
the orignal model has
3 conv_bn
1 pool
2 conv_bn
1 pool
3x inception a
1x inception b
4x inception c
1x inception d
2x inception e
1 conv_bn
1 adaptive pool 2d

dropout
flatten

fully connected layer

===================================
for our model, we are gonna just makeit smaller so that it trains faster, also cifar10 does not have the 1000 classes in imagenet lol
'''

class InceptionModel1(Module):
    def __init__(self, channels_in, class_num = 10):
        super(InceptionModel1, self).__init__()
        # remember, i must be able to extract the feature maps of each of the convolution layers, and as such, i must design my network around that as well

        # if this one is false, it will return feature maps. This would be found at the return funtion in the forward function
        self.PCA = False
        # input is N, 3, 32, 32
        self.layer1 = Sequential(
            Conv2d_BN(channels_in = channels_in, channels_out= 32, kernel_size=3, stride=2, padding=1),
            MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1)
             )
        # N, 32, 16, 16
        self.layer2 = Sequential(
            Conv2d_BN(channels_in = 32, channels_out= 64, kernel_size=3, stride=2, padding=1),
            MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1)
        )
        # N, 64, 8, 8

        # going into the inception layers
        # note that each of the components inside inception will ALWAYS retain the same width and height, and all the channels are concatenated together thats all
        self.incep1 = InceptionA(64, 16)
        # N, 240, 8, 8
        self.incep2 = InceptionB(240)
        # N, 720, 8, 8
        # inception 3 barely fits CIFAR10, i think this will be the last layer
        self.incep3 = InceptionC(720, 128)
        # N, 768, 8, 8
        self.incep4 = InceptionD(768)
        # N, 1280, 8, 8
        self.incep5 = InceptionE(1280)
        # N, 2048, 8, 8

        # going into the output layer now, last conv layer and then flattening it
        self.out = Sequential(
            # lowering the number of channels
            Conv2d_BN(channels_in = 2048, channels_out= 1024, kernel_size=1, stride=1, padding=0),
            AdaptiveAvgPool2d(1),
            Dropout(0.5)
        )
        # N, 1024, 1, 1

        # this one will then output it based on the number of classes, based on softmax i guess at this point
        self.fc = Linear(1024, class_num)

    def forward(self, x):
        x = self.layer1(x)
        fmap1 = x.clone()
        x = self.layer2(x)
        fmap2 = x.clone()
        x = self.incep1(x)
        fmap3 = x.clone()
        x = self.incep2(x)
        fmap4 = x.clone()
        x = self.incep3(x)
        fmap5 = x.clone()
        x = self.incep4(x)
        fmap6 = x.clone()
        x = self.incep5(x)
        fmap7 = x.clone()
        x = self.out(x)
        fmap8 = x.clone()
        # this one is to flatten, and retaining the batch size
        x = torch.flatten(x, 1)
        x = self.fc(x)
        fmap9 = x.clone()

        if self.PCA:
            return x, (fmap1, fmap2, fmap3, fmap3, fmap4, fmap5, fmap6, fmap7, fmap8, fmap9)
        else:
            return x

class InceptionModel2(Module):
    def __init__(self, channels_in, class_num = 10):
        super(InceptionModel2, self).__init__()
        # remember, i must be able to extract the feature maps of each of the convolution layers, and as such, i must design my network around that as well

        # if this one is false, it will return feature maps. This would be found at the return funtion in the forward function
        self.PCA = False
        # input is N, 3, 32, 32
        self.layer1 = Sequential(
            Conv2d_BN(channels_in = channels_in, channels_out= 32, kernel_size=3, stride=2, padding=1),
            MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1)
        )
        # N, 32, 16, 16
        self.layer2 = Sequential(
            Conv2d_BN(channels_in = 32, channels_out= 64, kernel_size=3, stride=2, padding=1),
            MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1)
        )
        # N, 64, 8, 8

        # going into the inception layers
        # note that each of the components inside inception will ALWAYS retain the same width and height, and all the channels are concatenated together thats all
        self.incep1 = InceptionA(64, 16)
        # N, 240, 8, 8
        self.incep2 = InceptionB(240)
        # N, 720, 8, 8
        # inception 3 barely fits CIFAR10, i think this will be the last layer
        self.incep3 = InceptionC(720, 128)
        # N, 768, 8, 8

        # going into the output layer now, last conv layer and then flattening it
        self.out = Sequential(
            # lowering the number of channels
            Conv2d_BN(channels_in = 768, channels_out= 320, kernel_size=1, stride=1, padding=0),
            AdaptiveAvgPool2d(1),
            Dropout(0.5)
        )
        # N, 1024, 1, 1

        # this one will then output it based on the number of classes, based on softmax i guess at this point
        self.fc = Linear(320, class_num)

    def forward(self, x):
        x = self.layer1(x)
        fmap1 = x.clone()
        x = self.layer2(x)
        fmap2 = x.clone()
        x = self.incep1(x)
        fmap3 = x.clone()
        x = self.incep2(x)
        fmap4 = x.clone()
        x = self.incep3(x)
        fmap5 = x.clone()
        x = self.out(x)
        fmap8 = x.clone()
        # this one is to flatten, and retaining the batch size
        x = torch.flatten(x, 1)
        x = self.fc(x)
        fmap9 = x.clone()

        if self.PCA:
            return x, (fmap1, fmap2, fmap3, fmap3, fmap4, fmap5, fmap8, fmap9)
        else:
            return x


# this is the intermediate modules
class Conv2d_BN(Module):
    def __init__(self, channels_in, channels_out, kernel_size, padding, stride=1, acti=LeakyReLU(0.2, inplace=True)):
        super(Conv2d_BN, self).__init__()
        self.conv2d_bn = Sequential(
            Conv2d(channels_in, channels_out, kernel_size, stride, padding, bias=False),
            BatchNorm2d(channels_out),
            acti
        )

    def forward(self, x):
        return self.conv2d_bn(x)

class InceptionA(Module):
    def __init__(self, channels_in, pool_channels):
        super(InceptionA, self).__init__()
        self.branch1x1 = Conv2d_BN(channels_in, 64, 1, stride=1, padding=0)  # 64 channels
        self.branch5x5 = Sequential(
            Conv2d_BN(channels_in, 48, 1, stride=1, padding=0),
            Conv2d_BN(48, 64, 5, stride=1, padding=2)
        )  # 64 channels
        self.branch3x3dbl = Sequential(
            Conv2d_BN(channels_in, 64, 1, stride=1, padding=0),
            Conv2d_BN(64, 96, 3, stride=1, padding=1),
            Conv2d_BN(96, 96, 3, stride=1, padding=1)
        )  # 96 channels
        self.branch_pool = Sequential(
            AvgPool2d(3, stride=1, padding=1),
            Conv2d_BN(channels_in, pool_channels, 1, stride=1, padding=0)
        )  # pool_channels

    def forward(self, x):
        outputs = [self.branch1x1(x), self.branch5x5(x), self.branch3x3dbl(x), self.branch_pool(x)]
        # 64 + 64 + 96 + pool_channels
        return torch.cat(outputs, 1)

class InceptionB(Module):
    def __init__(self, channels_in):
        super(InceptionB, self).__init__()
        self.branch3x3 = Conv2d_BN(channels_in, 384, 3, stride=2, padding=1)  # 384 channels
        self.branch3x3dbl = Sequential(
            Conv2d_BN(channels_in, 64, 1, padding=0),
            Conv2d_BN(64, 96, 3, padding=1),
            Conv2d_BN(96, 96, 3, stride=2, padding=1)
        )  # 96 channels
        self.branch_pool = MaxPool2d(3, stride=2, padding=1)  # channels_in

    def forward(self, x):
        outputs = [self.branch3x3(x), self.branch3x3dbl(x), self.branch_pool(x)]
        # 384 + 96 + channels_in
        return torch.cat(outputs, 1)

class InceptionC(Module):
    def __init__(self, channels_in, channels_7x7):
        super(InceptionC, self).__init__()
        self.branch1x1 = Conv2d_BN(channels_in, 192, 1, stride=1, padding=0)  # 192 channels
        self.branch7x7 = Sequential(
            Conv2d_BN(channels_in, channels_7x7, 1, stride=1, padding=0),
            Conv2d_BN(channels_7x7, channels_7x7, (1, 7), stride=1, padding=(0, 3)),
            Conv2d_BN(channels_7x7, 192, (7, 1), stride=1, padding=(3, 0))
        )  # 192 channels
        self.branch7x7dbl = Sequential(
            Conv2d_BN(channels_in, channels_7x7, 1, stride=1, padding=0),
            Conv2d_BN(channels_7x7, channels_7x7, (7, 1), stride=1, padding=(3, 0)),
            Conv2d_BN(channels_7x7, channels_7x7, (1, 7), stride=1, padding=(0, 3)),
            Conv2d_BN(channels_7x7, channels_7x7, (7, 1), stride=1, padding=(3, 0)),
            Conv2d_BN(channels_7x7, 192, (1, 7), stride=1, padding=(0, 3))
        )  # 192 channels
        self.branch_pool = Sequential(
            AvgPool2d(3, stride=1, padding=1),
            Conv2d_BN(channels_in, 192, 1, stride=1, padding=0)
        )  # 192 channels

    def forward(self, x):
        outputs = [self.branch1x1(x), self.branch7x7(x), self.branch7x7dbl(x), self.branch_pool(x)]
        # 192 + 192 + 192 + 192 = 768 channels
        return torch.cat(outputs, 1)

class InceptionD(Module):
    def __init__(self, channels_in):
        super(InceptionD, self).__init__()
        self.branch3x3 = Sequential(
            Conv2d_BN(channels_in, 192, 1, stride=1, padding=0),
            Conv2d_BN(192, 320, 3, stride=2, padding=1)
        )  # 320 channels
        self.branch7x7x3 = Sequential(
            Conv2d_BN(channels_in, 192, 1, stride=1, padding=0),
            Conv2d_BN(192, 192, (1, 7), stride=1, padding=(0, 3)),
            Conv2d_BN(192, 192, (7, 1), stride=1, padding=(3, 0)),
            Conv2d_BN(192, 192, 3, stride=2, padding=1)
        )  # 192 chnnels
        self.branch_pool = MaxPool2d(3, stride=2, padding=1)  # channels_in

    def forward(self, x):
        outputs = [self.branch3x3(x), self.branch7x7x3(x), self.branch_pool(x)]
        # 320 + 192 + channels_in
        return torch.cat(outputs, 1)

class InceptionE(Module):
    def __init__(self, channels_in):
        super(InceptionE, self).__init__()
        self.branch1x1 = Conv2d_BN(channels_in, 320, 1, stride=1, padding=0)  # 320 channels

        self.branch3x3_1 = Conv2d_BN(channels_in, 384, 1, stride=1, padding=0)
        self.branch3x3_2a = Conv2d_BN(384, 384, (1, 3), stride=1, padding=(0, 1))
        self.branch3x3_2b = Conv2d_BN(384, 384, (3, 1), stride=1, padding=(1, 0))
        # 768 channels

        self.branch3x3dbl_1 = Sequential(
            Conv2d_BN(channels_in, 448, 1, stride=1, padding=0),
            Conv2d_BN(448, 384, 3, stride=1, padding=1)
        )
        self.branch3x3dbl_2a = Conv2d_BN(384, 384, (1, 3), stride=1, padding=(0, 1))
        self.branch3x3dbl_2b = Conv2d_BN(384, 384, (3, 1), stride=1, padding=(1, 0))
        # 768 channels

        self.branch_pool = Sequential(
            AvgPool2d(3, stride=1, padding=1),
            Conv2d_BN(channels_in, 192, 1, stride=1, padding=0)
        )  # 192 channels
    def forward(self, x):
        branch1x1 = self.branch1x1(x)

        branch3x3 = self.branch3x3_1(x)
        branch3x3 = torch.cat([self.branch3x3_2a(branch3x3), self.branch3x3_2b(branch3x3)], 1)

        branch3x3dbl = self.branch3x3dbl_1(x)
        branch3x3dbl = torch.cat([self.branch3x3dbl_2a(branch3x3dbl), self.branch3x3dbl_2b(branch3x3dbl)], 1)

        branch_pool = self.branch_pool(x)

        outputs = [branch1x1, branch3x3, branch3x3dbl, branch_pool]
        # 320 + 768 + 768 + 192 = 2048 channels
        return torch.cat(outputs, 1)

# %%
# model = InceptionModel1(channels_in=3, class_num=10)
# print(summary(model, (64, 3, 32, 32)))

# %%
# model = InceptionModel2(channels_in=3, class_num=10)
# print(summary(model, (64, 3, 32, 32)))

# %%
STUDENTID = 567     # this will be used for random states

import torch
import torchvision
import torchvision.transforms as transforms
import numpy as np
import logging
from utils import *
import torch.optim as optim
import os
import shutil
import os
import time

# Define data transformations
transform = transforms.Compose([
    transforms.ToTensor(),  # Convert PIL Image to PyTorch Tensor
    # this normalization is industry standard, it seems 
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))  # Normalize the data
])


# define the label transformations, from int64 to float32
transform_label = transforms.Compose([
    #transforms.ToTensor()
])

# Download and load CIFAR-100 datasets
train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, transform=transform, download=True, target_transform=transform_label)
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, transform=transform, download=True, target_transform=transform_label)


# Calculate the sizes for train, validation, and test sets
train_size = int(0.8 * len(train_dataset))
valid_size = len(train_dataset) - train_size

# Split the train dataset into train and validation sets using a random seed
train_dataset, valid_dataset = torch.utils.data.random_split(train_dataset, [train_size, valid_size], generator=torch.Generator().manual_seed(STUDENTID))

# Create data loaders for training, validation, and test sets
batch_size = 64
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# Print dataset sizes
print("Number of training examples:", len(train_dataset))
print("Number of validation examples:", len(valid_dataset))
print("Number of test examples:", len(test_dataset))

# creating a model that automatically runs the forward function i guess, since it is easier
import torch
import torch.nn as nn
import torch.optim as optim
from utils import *
from customModels import *
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Number of training examples: 40000
# Number of validation examples: 10000
# Number of test examples: 10000

# %%
model = InceptionModel1(channels_in=3, class_num=10)
modelName = 'InceptionModel1_corect_data_aug'

argDict = {
    'lr': 0.001,
    'maxEpoch': 250,
    'idleEpoch': 25,
    'outputName': modelName,
    'optimizer': optim.SGD(model.parameters(), lr=0.001),
    'criterion': nn.CrossEntropyLoss()
}

# setting up the logger
loggerName = modelName + '.log'
loggerName = os.path.join(argDict['outputName'], loggerName)
logger = MyLogger(loggerName)
argDict['logger'] = logger

# just to initilalize the files
logger.log('training starts here')

start_time = time.time()

# training and saving model to dictionary
outputDict = train(model, argDict, train_loader, val_loader, test_loader)

# loading the best model, and then sending it off to testing
model = load_model_from_file(model, argDict['outputName'], argDict['outputName'])

test_accuracy = test(model, argDict, test_loader)
tempString = 'testing accuracy of ' + argDict['outputName'] + " is: " + str(test_accuracy)
logger.log(tempString)

argDict['test_accuracy'] = str(test_accuracy)

# timing the thing as well
end_time = time.time()
execution_time = end_time - start_time
argDict['time_taken'] = execution_time
save_dict_to_file(outputDict, argDict['outputName'], argDict['outputName'])

del model
del argDict

# Define the folder you want to zip and the output zip file name
folder_to_zip = modelName
output_zip_file = modelName + ".zip"

# Use shutil.make_archive to create the zip file
shutil.make_archive(output_zip_file, 'zip', folder_to_zip)

os.rename(output_zip_file + '.zip', output_zip_file)
# Out:
# training starts here
# currently at epoch 0 train accuracy: tensor(0.2977, device='cuda:0') loss of: 1.9139624311447143 eval accuracy: tensor(0.3659, device='cuda:0')
# currently at epoch 1 train accuracy: tensor(0.3950, device='cuda:0') loss of: 1.6579586708068847 eval accuracy: tensor(0.4082, device='cuda:0')
# currently at epoch 2 train accuracy: tensor(0.4355, device='cuda:0') loss of: 1.5506487993240357 eval accuracy: tensor(0.4252, device='cuda:0')
# currently at epoch 3 train accuracy: tensor(0.4637, device='cuda:0') loss of: 1.4778195711135864 eval accuracy: tensor(0.4385, device='cuda:0')
# currently at epoch 4 train accuracy: tensor(0.4830, device='cuda:0') loss of: 1.4231788429260255 eval accuracy: tensor(0.4549, device='cuda:0')
# currently at epoch 5 train accuracy: tensor(0.5033, device='cuda:0') loss of: 1.3742335538864137 eval accuracy: tensor(0.4695, device='cuda:0')
# currently at epoch 6 train accuracy: tensor(0.5205, device='cuda:0') loss of: 1.334362661552429 eval accuracy: tensor(0.4729, device='cuda:0')
# currently at epoch 7 train accuracy: tensor(0.5326, device='cuda:0') loss of: 1.2961373235702514 eval accuracy: tensor(0.4769, device='cuda:0')
# currently at epoch 8 train accuracy: tensor(0.5448, device='cuda:0') loss of: 1.263635352039337 eval accuracy: tensor(0.4842, device='cuda:0')
# currently at epoch 9 train accuracy: tensor(0.5576, device='cuda:0') loss of: 1.2226722626686095 eval accuracy: tensor(0.4857, device='cuda:0')
# currently at epoch 10 train accuracy: tensor(0.5723, device='cuda:0') loss of: 1.191570442199707 eval accuracy: tensor(0.4882, device='cuda:0')
# currently at epoch 11 train accuracy: tensor(0.5831, device='cuda:0') loss of: 1.1596110456466675 eval accuracy: tensor(0.4916, device='cuda:0')
# currently at epoch 12 train accuracy: tensor(0.5960, device='cuda:0') loss of: 1.1253405313491822 eval accuracy: tensor(0.4928, device='cuda:0')
# currently at epoch 13 train accuracy: tensor(0.6081, device='cuda:0') loss of: 1.0949190028190612 eval accuracy: tensor(0.4949, device='cuda:0')
# currently at epoch 14 train accuracy: tensor(0.6178, device='cuda:0') loss of: 1.0640266571044923 eval accuracy: tensor(0.4969, device='cuda:0')
# currently at epoch 15 train accuracy: tensor(0.6291, device='cuda:0') loss of: 1.0398335466384887 eval accuracy: tensor(0.4967, device='cuda:0')
# currently at epoch 16 train accuracy: tensor(0.6407, device='cuda:0') loss of: 1.002510860824585 eval accuracy: tensor(0.4972, device='cuda:0')
# currently at epoch 17 train accuracy: tensor(0.6507, device='cuda:0') loss of: 0.9782911080360412 eval accuracy: tensor(0.4958, device='cuda:0')
# currently at epoch 18 train accuracy: tensor(0.6608, device='cuda:0') loss of: 0.9472979290008545 eval accuracy: tensor(0.4926, device='cuda:0')
# currently at epoch 19 train accuracy: tensor(0.6670, device='cuda:0') loss of: 0.92350612449646 eval accuracy: tensor(0.5005, device='cuda:0')
# currently at epoch 20 train accuracy: tensor(0.6781, device='cuda:0') loss of: 0.8918709384918213 eval accuracy: tensor(0.4926, device='cuda:0')
# currently at epoch 21 train accuracy: tensor(0.6905, device='cuda:0') loss of: 0.8658389695167541 eval accuracy: tensor(0.4929, device='cuda:0')
# currently at epoch 22 train accuracy: tensor(0.7024, device='cuda:0') loss of: 0.8389010265827179 eval accuracy: tensor(0.4910, device='cuda:0')
# currently at epoch 23 train accuracy: tensor(0.7110, device='cuda:0') loss of: 0.8125702886104583 eval accuracy: tensor(0.4907, device='cuda:0')
# currently at epoch 24 train accuracy: tensor(0.7208, device='cuda:0') loss of: 0.7842530466079712 eval accuracy: tensor(0.4924, device='cuda:0')
# currently at epoch 25 train accuracy: tensor(0.7299, device='cuda:0') loss of: 0.7600184701919556 eval accuracy: tensor(0.4845, device='cuda:0')
# currently at epoch 26 train accuracy: tensor(0.7378, device='cuda:0') loss of: 0.7360494643211365 eval accuracy: tensor(0.4848, device='cuda:0')
# currently at epoch 27 train accuracy: tensor(0.7469, device='cuda:0') loss of: 0.7071343006610871 eval accuracy: tensor(0.4903, device='cuda:0')
# currently at epoch 28 train accuracy: tensor(0.7557, device='cuda:0') loss of: 0.6900523028373718 eval accuracy: tensor(0.4859, device='cuda:0')
# currently at epoch 29 train accuracy: tensor(0.7625, device='cuda:0') loss of: 0.6653204597473145 eval accuracy: tensor(0.4834, device='cuda:0')
# currently at epoch 30 train accuracy: tensor(0.7725, device='cuda:0') loss of: 0.6391126592636108 eval accuracy: tensor(0.4914, device='cuda:0')
# currently at epoch 31 train accuracy: tensor(0.7795, device='cuda:0') loss of: 0.6199206895828248 eval accuracy: tensor(0.4837, device='cuda:0')
# currently at epoch 32 train accuracy: tensor(0.7812, device='cuda:0') loss of: 0.6069244769096375 eval accuracy: tensor(0.4866, device='cuda:0')
# currently at epoch 33 train accuracy: tensor(0.7954, device='cuda:0') loss of: 0.5762611554145813 eval accuracy: tensor(0.4883, device='cuda:0')
# currently at epoch 34 train accuracy: tensor(0.8048, device='cuda:0') loss of: 0.5537638359069824 eval accuracy: tensor(0.4826, device='cuda:0')
# currently at epoch 35 train accuracy: tensor(0.8088, device='cuda:0') loss of: 0.537163920879364 eval accuracy: tensor(0.4863, device='cuda:0')
# currently at epoch 36 train accuracy: tensor(0.8136, device='cuda:0') loss of: 0.5259792934417724 eval accuracy: tensor(0.4818, device='cuda:0')
# currently at epoch 37 train accuracy: tensor(0.8174, device='cuda:0') loss of: 0.5093998795747757 eval accuracy: tensor(0.4896, device='cuda:0')
# currently at epoch 38 train accuracy: tensor(0.8267, device='cuda:0') loss of: 0.4899410866975784 eval accuracy: tensor(0.4929, device='cuda:0')
# currently at epoch 39 train accuracy: tensor(0.8314, device='cuda:0') loss of: 0.4730540694952011 eval accuracy: tensor(0.4862, device='cuda:0')
# currently at epoch 40 train accuracy: tensor(0.8413, device='cuda:0') loss of: 0.4537700779914856 eval accuracy: tensor(0.4865, device='cuda:0')
# currently at epoch 41 train accuracy: tensor(0.8452, device='cuda:0') loss of: 0.4398407862186432 eval accuracy: tensor(0.4928, device='cuda:0')
# currently at epoch 42 train accuracy: tensor(0.8496, device='cuda:0') loss of: 0.4248492376565933 eval accuracy: tensor(0.4895, device='cuda:0')
# currently at epoch 43 train accuracy: tensor(0.8570, device='cuda:0') loss of: 0.40927003903388975 eval accuracy: tensor(0.4812, device='cuda:0')
# currently at epoch 44 train accuracy: tensor(0.8575, device='cuda:0') loss of: 0.40381513905525207 eval accuracy: tensor(0.4806, device='cuda:0')
# currently at epoch 45 train accuracy: tensor(0.8616, device='cuda:0') loss of: 0.39213597836494446 eval accuracy: tensor(0.4849, device='cuda:0')
# testing accuracy of InceptionModel1 is: tensor(0.4991, device='cuda:0')

# %%
model = InceptionModel2(channels_in=3, class_num=10)
modelName = 'InceptionModel2_corect_data_aug'

argDict = {
    'lr': 0.001,
    'maxEpoch': 250,
    'idleEpoch': 25,
    'outputName': modelName,
    'optimizer': optim.SGD(model.parameters(), lr=0.001),
    'criterion': nn.CrossEntropyLoss()
}

# setting up the logger
loggerName = modelName + '.log'
loggerName = os.path.join(argDict['outputName'], loggerName)
logger = MyLogger(loggerName)
argDict['logger'] = logger

# just to initilalize the files
logger.log('training starts here')

start_time = time.time()

# training and saving model to dictionary
outputDict = train(model, argDict, train_loader, val_loader, test_loader)

# loading the best model, and then sending it off to testing
model = load_model_from_file(model, argDict['outputName'], argDict['outputName'])

test_accuracy = test(model, argDict, test_loader)
tempString = 'testing accuracy of ' + argDict['outputName'] + " is: " + str(test_accuracy)
logger.log(tempString)

argDict['test_accuracy'] = str(test_accuracy)

# timing the thing as well
end_time = time.time()
execution_time = end_time - start_time
argDict['time_taken'] = execution_time
save_dict_to_file(outputDict, argDict['outputName'], argDict['outputName'])

del model
del argDict

# Define the folder you want to zip and the output zip file name
folder_to_zip = modelName
output_zip_file = modelName + ".zip"

# Use shutil.make_archive to create the zip file
shutil.make_archive(output_zip_file, 'zip', folder_to_zip)

os.rename(output_zip_file + '.zip', output_zip_file)
# Out:
# training starts here
# currently at epoch 0 train accuracy: tensor(0.2690, device='cuda:0') loss of: 1.9971303442001342 eval accuracy: tensor(0.3450, device='cuda:0')
# currently at epoch 1 train accuracy: tensor(0.3749, device='cuda:0') loss of: 1.7206240447998047 eval accuracy: tensor(0.3954, device='cuda:0')
# currently at epoch 2 train accuracy: tensor(0.4236, device='cuda:0') loss of: 1.5942696945190429 eval accuracy: tensor(0.4252, device='cuda:0')
# currently at epoch 3 train accuracy: tensor(0.4491, device='cuda:0') loss of: 1.5212346126556398 eval accuracy: tensor(0.4426, device='cuda:0')
# currently at epoch 4 train accuracy: tensor(0.4744, device='cuda:0') loss of: 1.4651712760925293 eval accuracy: tensor(0.4549, device='cuda:0')
# currently at epoch 5 train accuracy: tensor(0.4889, device='cuda:0') loss of: 1.4201392400741577 eval accuracy: tensor(0.4711, device='cuda:0')
# currently at epoch 6 train accuracy: tensor(0.5067, device='cuda:0') loss of: 1.3809497606277465 eval accuracy: tensor(0.4797, device='cuda:0')
# currently at epoch 7 train accuracy: tensor(0.5185, device='cuda:0') loss of: 1.3501374410629272 eval accuracy: tensor(0.4847, device='cuda:0')
# currently at epoch 8 train accuracy: tensor(0.5325, device='cuda:0') loss of: 1.3161715029716492 eval accuracy: tensor(0.4893, device='cuda:0')
# currently at epoch 9 train accuracy: tensor(0.5423, device='cuda:0') loss of: 1.2891542546272279 eval accuracy: tensor(0.5001, device='cuda:0')
# currently at epoch 10 train accuracy: tensor(0.5527, device='cuda:0') loss of: 1.2582532242774964 eval accuracy: tensor(0.5010, device='cuda:0')
# currently at epoch 11 train accuracy: tensor(0.5583, device='cuda:0') loss of: 1.2379254721641542 eval accuracy: tensor(0.5102, device='cuda:0')
# currently at epoch 12 train accuracy: tensor(0.5660, device='cuda:0') loss of: 1.2178717851638794 eval accuracy: tensor(0.5112, device='cuda:0')
# currently at epoch 13 train accuracy: tensor(0.5743, device='cuda:0') loss of: 1.1928321172714234 eval accuracy: tensor(0.5113, device='cuda:0')
# currently at epoch 14 train accuracy: tensor(0.5850, device='cuda:0') loss of: 1.173311763191223 eval accuracy: tensor(0.5163, device='cuda:0')
# currently at epoch 15 train accuracy: tensor(0.5905, device='cuda:0') loss of: 1.1573499458312988 eval accuracy: tensor(0.5219, device='cuda:0')
# currently at epoch 16 train accuracy: tensor(0.5992, device='cuda:0') loss of: 1.1308319805145264 eval accuracy: tensor(0.5227, device='cuda:0')
# currently at epoch 17 train accuracy: tensor(0.6044, device='cuda:0') loss of: 1.1149411131858826 eval accuracy: tensor(0.5267, device='cuda:0')
# currently at epoch 18 train accuracy: tensor(0.6150, device='cuda:0') loss of: 1.0972986630439758 eval accuracy: tensor(0.5192, device='cuda:0')
# currently at epoch 19 train accuracy: tensor(0.6202, device='cuda:0') loss of: 1.0734632276535034 eval accuracy: tensor(0.5298, device='cuda:0')
# currently at epoch 20 train accuracy: tensor(0.6287, device='cuda:0') loss of: 1.0574024297714233 eval accuracy: tensor(0.5223, device='cuda:0')
# currently at epoch 21 train accuracy: tensor(0.6352, device='cuda:0') loss of: 1.03184069480896 eval accuracy: tensor(0.5257, device='cuda:0')
# currently at epoch 22 train accuracy: tensor(0.6417, device='cuda:0') loss of: 1.019032329273224 eval accuracy: tensor(0.5281, device='cuda:0')
# currently at epoch 23 train accuracy: tensor(0.6464, device='cuda:0') loss of: 1.0081344546318054 eval accuracy: tensor(0.5311, device='cuda:0')
# currently at epoch 24 train accuracy: tensor(0.6529, device='cuda:0') loss of: 0.9864004111289978 eval accuracy: tensor(0.5273, device='cuda:0')
# currently at epoch 25 train accuracy: tensor(0.6608, device='cuda:0') loss of: 0.9674463012695312 eval accuracy: tensor(0.5244, device='cuda:0')
# currently at epoch 26 train accuracy: tensor(0.6618, device='cuda:0') loss of: 0.9533497137069702 eval accuracy: tensor(0.5278, device='cuda:0')
# currently at epoch 27 train accuracy: tensor(0.6711, device='cuda:0') loss of: 0.9385658931732178 eval accuracy: tensor(0.5284, device='cuda:0')
# currently at epoch 28 train accuracy: tensor(0.6772, device='cuda:0') loss of: 0.9217077858924866 eval accuracy: tensor(0.5297, device='cuda:0')
# currently at epoch 29 train accuracy: tensor(0.6847, device='cuda:0') loss of: 0.9044421245574951 eval accuracy: tensor(0.5254, device='cuda:0')
# currently at epoch 30 train accuracy: tensor(0.6893, device='cuda:0') loss of: 0.887900614452362 eval accuracy: tensor(0.5316, device='cuda:0')
# currently at epoch 31 train accuracy: tensor(0.6919, device='cuda:0') loss of: 0.8738443552970886 eval accuracy: tensor(0.5253, device='cuda:0')
# currently at epoch 32 train accuracy: tensor(0.6985, device='cuda:0') loss of: 0.8589430953025818 eval accuracy: tensor(0.5319, device='cuda:0')
# currently at epoch 33 train accuracy: tensor(0.7055, device='cuda:0') loss of: 0.8390136547088624 eval accuracy: tensor(0.5285, device='cuda:0')
# currently at epoch 34 train accuracy: tensor(0.7088, device='cuda:0') loss of: 0.8318337543487548 eval accuracy: tensor(0.5251, device='cuda:0')
# currently at epoch 35 train accuracy: tensor(0.7137, device='cuda:0') loss of: 0.8141521955966949 eval accuracy: tensor(0.5270, device='cuda:0')
# currently at epoch 36 train accuracy: tensor(0.7178, device='cuda:0') loss of: 0.8018778489112854 eval accuracy: tensor(0.5284, device='cuda:0')
# currently at epoch 37 train accuracy: tensor(0.7232, device='cuda:0') loss of: 0.7905115386962891 eval accuracy: tensor(0.5338, device='cuda:0')
# currently at epoch 38 train accuracy: tensor(0.7278, device='cuda:0') loss of: 0.773184594964981 eval accuracy: tensor(0.5268, device='cuda:0')
# currently at epoch 39 train accuracy: tensor(0.7341, device='cuda:0') loss of: 0.7587793412208557 eval accuracy: tensor(0.5337, device='cuda:0')
# currently at epoch 40 train accuracy: tensor(0.7375, device='cuda:0') loss of: 0.7469227386951447 eval accuracy: tensor(0.5318, device='cuda:0')
# currently at epoch 41 train accuracy: tensor(0.7414, device='cuda:0') loss of: 0.733726586008072 eval accuracy: tensor(0.5288, device='cuda:0')
# currently at epoch 42 train accuracy: tensor(0.7474, device='cuda:0') loss of: 0.7198800262451172 eval accuracy: tensor(0.5268, device='cuda:0')
# currently at epoch 43 train accuracy: tensor(0.7532, device='cuda:0') loss of: 0.7042466099739074 eval accuracy: tensor(0.5300, device='cuda:0')
# currently at epoch 44 train accuracy: tensor(0.7552, device='cuda:0') loss of: 0.6983714254856109 eval accuracy: tensor(0.5263, device='cuda:0')
# currently at epoch 45 train accuracy: tensor(0.7606, device='cuda:0') loss of: 0.681647465133667 eval accuracy: tensor(0.5276, device='cuda:0')
# currently at epoch 46 train accuracy: tensor(0.7645, device='cuda:0') loss of: 0.6732206661701202 eval accuracy: tensor(0.5274, device='cuda:0')
# currently at epoch 47 train accuracy: tensor(0.7690, device='cuda:0') loss of: 0.6639629400253296 eval accuracy: tensor(0.5231, device='cuda:0')
# currently at epoch 48 train accuracy: tensor(0.7743, device='cuda:0') loss of: 0.6440162521362305 eval accuracy: tensor(0.5287, device='cuda:0')
# currently at epoch 49 train accuracy: tensor(0.7750, device='cuda:0') loss of: 0.635968426656723 eval accuracy: tensor(0.5237, device='cuda:0')
# currently at epoch 50 train accuracy: tensor(0.7806, device='cuda:0') loss of: 0.6237206735134124 eval accuracy: tensor(0.5238, device='cuda:0')
# currently at epoch 51 train accuracy: tensor(0.7839, device='cuda:0') loss of: 0.6141276957511902 eval accuracy: tensor(0.5253, device='cuda:0')
# currently at epoch 52 train accuracy: tensor(0.7882, device='cuda:0') loss of: 0.5984898552894592 eval accuracy: tensor(0.5206, device='cuda:0')
# currently at epoch 53 train accuracy: tensor(0.7916, device='cuda:0') loss of: 0.5906754627227783 eval accuracy: tensor(0.5199, device='cuda:0')
# currently at epoch 54 train accuracy: tensor(0.7973, device='cuda:0') loss of: 0.5776149385929108 eval accuracy: tensor(0.5253, device='cuda:0')
# currently at epoch 55 train accuracy: tensor(0.8036, device='cuda:0') loss of: 0.563962424659729 eval accuracy: tensor(0.5182, device='cuda:0')
# currently at epoch 56 train accuracy: tensor(0.8052, device='cuda:0') loss of: 0.5567284275054931 eval accuracy: tensor(0.5221, device='cuda:0')
# currently at epoch 57 train accuracy: tensor(0.8052, device='cuda:0') loss of: 0.5524147392272949 eval accuracy: tensor(0.5147, device='cuda:0')
# currently at epoch 58 train accuracy: tensor(0.8103, device='cuda:0') loss of: 0.5413395697116852 eval accuracy: tensor(0.5228, device='cuda:0')
# currently at epoch 59 train accuracy: tensor(0.8133, device='cuda:0') loss of: 0.5348190361499786 eval accuracy: tensor(0.5216, device='cuda:0')
# currently at epoch 60 train accuracy: tensor(0.8168, device='cuda:0') loss of: 0.5224045339107514 eval accuracy: tensor(0.5210, device='cuda:0')
# currently at epoch 61 train accuracy: tensor(0.8219, device='cuda:0') loss of: 0.5100982964992523 eval accuracy: tensor(0.5280, device='cuda:0')
# currently at epoch 62 train accuracy: tensor(0.8214, device='cuda:0') loss of: 0.5075554978847504 eval accuracy: tensor(0.5219, device='cuda:0')
# currently at epoch 63 train accuracy: tensor(0.8243, device='cuda:0') loss of: 0.4979705668449402 eval accuracy: tensor(0.5215, device='cuda:0')
# testing accuracy of InceptionModel2 is: tensor(0.5255, device='cuda:0')

# %%
model = InceptionModel2(channels_in=3, class_num=10)
modelName = 'InceptionModel2_data_aug'

argDict = {
    'lr': 0.001,
    'maxEpoch': 250,
    'idleEpoch': 25,
    'outputName': modelName,
    'optimizer': optim.SGD(model.parameters(), lr=0.001),
    'criterion': nn.CrossEntropyLoss()
}

# setting up the logger
loggerName = modelName + '.log'
loggerName = os.path.join(argDict['outputName'], loggerName)
logger = MyLogger(loggerName)
argDict['logger'] = logger

# just to initilalize the files
logger.log('training starts here')

start_time = time.time()

# training and saving model to dictionary
outputDict = train(model, argDict, train_loader, val_loader, test_loader)

# loading the best model, and then sending it off to testing
model = load_model_from_file(model, argDict['outputName'], argDict['outputName'])

test_accuracy = test(model, argDict, test_loader)
tempString = 'testing accuracy of ' + argDict['outputName'] + " is: " + str(test_accuracy)
logger.log(tempString)

argDict['test_accuracy'] = str(test_accuracy)

# timing the thing as well
end_time = time.time()
execution_time = end_time - start_time
argDict['time_taken'] = execution_time
save_dict_to_file(outputDict, argDict['outputName'], argDict['outputName'])

del model
del argDict

# Define the folder you want to zip and the output zip file name
folder_to_zip = modelName
output_zip_file = modelName + ".zip"

# Use shutil.make_archive to create the zip file
shutil.make_archive(output_zip_file, 'zip', folder_to_zip)

os.rename(output_zip_file + '.zip', output_zip_file)
