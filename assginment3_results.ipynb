# %% [markdown]
# # this one just serves as a record book since i dont have anything to take note of anything right now
# This is the data for the ANN, 10, 50, 100, 200.
# 0.006192675791680813, 0.006119116675108671, 0.006391247268766165, 0.0064037879928946495
# 0.008821262046694756, 0.0398385226726532, 0.018670564517378807, 0.05045648291707039
# 0.00882126281719863, 0.03983853014739927, 0.01867056154960194, 0.05045648824085881
#
# This is from the RNN, it seems like it is doing not too bad at all
# 0.005845943000167608, 0.005511879920959473, 0.006309374235570431, 0.0059455204755067825
# 0.005717905703932047, 0.005790653172880411, 0.006159445270895958, 0.006167713087052107
# 0.005922454324323781, 0.006771929848776349, 0.006476119791952177, 0.00477819805240781
# ^ has a lower error rate compared to ANN, which is expected I guess
#
# Gated recurrent neural network
# 0.006139762233942747, 0.0052437931299209595, 0.005078422836959362, 0.004649152513593435
# 0.006213137414306402, 0.0056012943387031555, 0.004986939486116171, 0.004533249884843826
# 0.00594688295826099, 0.0052734576199427174, 0.004359913922879963, 0.004311974453528195
#
# LSTM
# 0.005666110664606094, 0.0051691061817109585, 0.004818581975996494, 0.005251029971987009
# 0.005700644571334124, 0.005771602503955364, 0.004388122353702784, 0.005210600793361664
# 0.005965696927212817, 0.0059601555530973595, 0.005411266531159616, 0.0051768285421392194
#
# the input size should be (41757, 5) (41757, 1)
# second one is the output i guess

# %% [markdown]
# # this one is for question 4
# RNN
# train val test
# 24 72 168
# 0.008267788216471672, 0.008678571321070194, 0.009062702767550945
# 0.009120982140302658, 0.009229352697730064, 0.00990812387317419
# 0.009135509490143986, 0.008531683716735836, 0.008274742524714033
#
# GRU
# 0.008447050116956234, 0.009087145328521729, 0.009173167869448662
# 0.009641679003834724, 0.009619716554880142, 0.009948858991265297
# 0.007712808211516873, 0.009497265828423035, 0.008453397535972568
#
# LSTM
# 0.008439522236585617, 0.008636465296149254, 0.008787885308265686
# 0.009941830299794674, 0.008975489065051079, 0.009435775689780712
# 0.00954974567702364, 0.008981534948579417, 0.009361242623292227

# %% [markdown]
# this is notes on the size of the inputs with the different slicing operations
#
# 24
# (41757, 5) (41757, 1)
# (41781, 5) (41781, 1)
# (41733, 5) (41733, 1)
#
# 72
# (41757, 5) (41757, 1)
# (41829, 5) (41829, 1)
# (41685, 5) (41685, 1)
#
# 168
# (41757, 5) (41757, 1)
# (41925, 5) (41925, 1)
# (41589, 5) (41589, 1)
